# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Metadata" data-toc-modified-id="Metadata-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Metadata</a></span></li><li><span><a href="#Trees" data-toc-modified-id="Trees-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Trees</a></span></li><li><span><a href="#Bracken-counts" data-toc-modified-id="Bracken-counts-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Bracken counts</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></li><li><span><a href="#Alpha-div-calc" data-toc-modified-id="Alpha-div-calc-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Alpha div calc</a></span><ul class="toc-item"><li><span><a href="#Summary-of-taxonomic-groups" data-toc-modified-id="Summary-of-taxonomic-groups-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Summary of taxonomic groups</a></span><ul class="toc-item"><li><span><a href="#No.-of-phyla" data-toc-modified-id="No.-of-phyla-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>No. of phyla</a></span></li><li><span><a href="#No.-of-genera" data-toc-modified-id="No.-of-genera-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>No. of genera</a></span></li><li><span><a href="#Treponema" data-toc-modified-id="Treponema-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Treponema</a></span></li><li><span><a href="#Methanogens" data-toc-modified-id="Methanogens-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Methanogens</a></span></li><li><span><a href="#Christ." data-toc-modified-id="Christ.-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>Christ.</a></span></li></ul></li><li><span><a href="#Formatting" data-toc-modified-id="Formatting-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Formatting</a></span></li></ul></li><li><span><a href="#Alpha-div-summary" data-toc-modified-id="Alpha-div-summary-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Alpha div summary</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Westernized" data-toc-modified-id="Westernized-6.0.1"><span class="toc-item-num">6.0.1&nbsp;&nbsp;</span>Westernized</a></span></li><li><span><a href="#Age" data-toc-modified-id="Age-6.0.2"><span class="toc-item-num">6.0.2&nbsp;&nbsp;</span>Age</a></span></li><li><span><a href="#Study-condition-&amp;-disease" data-toc-modified-id="Study-condition-&amp;-disease-6.0.3"><span class="toc-item-num">6.0.3&nbsp;&nbsp;</span>Study condition &amp; disease</a></span></li></ul></li><li><span><a href="#ANOVA:-full-dataset" data-toc-modified-id="ANOVA:-full-dataset-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ANOVA: full dataset</a></span><ul class="toc-item"><li><span><a href="#Westernized" data-toc-modified-id="Westernized-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Westernized</a></span></li><li><span><a href="#Study-condition" data-toc-modified-id="Study-condition-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Study condition</a></span></li><li><span><a href="#Disease" data-toc-modified-id="Disease-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Disease</a></span></li></ul></li><li><span><a href="#ANOVA:-filtered" data-toc-modified-id="ANOVA:-filtered-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ANOVA: filtered</a></span><ul class="toc-item"><li><span><a href="#Westernized" data-toc-modified-id="Westernized-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Westernized</a></span></li><li><span><a href="#Study-condition" data-toc-modified-id="Study-condition-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Study condition</a></span></li><li><span><a href="#Disease" data-toc-modified-id="Disease-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Disease</a></span></li></ul></li><li><span><a href="#lmer:-full-dataset" data-toc-modified-id="lmer:-full-dataset-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>lmer: full dataset</a></span><ul class="toc-item"><li><span><a href="#Westernized" data-toc-modified-id="Westernized-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Westernized</a></span><ul class="toc-item"><li><span><a href="#Westernized-*-gender" data-toc-modified-id="Westernized-*-gender-6.3.1.1"><span class="toc-item-num">6.3.1.1&nbsp;&nbsp;</span>Westernized * gender</a></span></li></ul></li><li><span><a href="#study-condition" data-toc-modified-id="study-condition-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>study condition</a></span></li><li><span><a href="#Disease" data-toc-modified-id="Disease-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Disease</a></span><ul class="toc-item"><li><span><a href="#Simplified" data-toc-modified-id="Simplified-6.3.3.1"><span class="toc-item-num">6.3.3.1&nbsp;&nbsp;</span>Simplified</a></span></li></ul></li></ul></li><li><span><a href="#lmer:-filtered" data-toc-modified-id="lmer:-filtered-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>lmer: filtered</a></span><ul class="toc-item"><li><span><a href="#Westernized" data-toc-modified-id="Westernized-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Westernized</a></span></li><li><span><a href="#Study-condition" data-toc-modified-id="Study-condition-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Study condition</a></span></li><li><span><a href="#Disease" data-toc-modified-id="Disease-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>Disease</a></span></li><li><span><a href="#BMI" data-toc-modified-id="BMI-6.4.4"><span class="toc-item-num">6.4.4&nbsp;&nbsp;</span>BMI</a></span></li><li><span><a href="#lmer:-westernization-summary" data-toc-modified-id="lmer:-westernization-summary-6.4.5"><span class="toc-item-num">6.4.5&nbsp;&nbsp;</span>lmer: westernization summary</a></span><ul class="toc-item"><li><span><a href="#PD_phy" data-toc-modified-id="PD_phy-6.4.5.1"><span class="toc-item-num">6.4.5.1&nbsp;&nbsp;</span>PD_phy</a></span></li><li><span><a href="#PD_trt" data-toc-modified-id="PD_trt-6.4.5.2"><span class="toc-item-num">6.4.5.2&nbsp;&nbsp;</span>PD_trt</a></span></li><li><span><a href="#Shannon" data-toc-modified-id="Shannon-6.4.5.3"><span class="toc-item-num">6.4.5.3&nbsp;&nbsp;</span>Shannon</a></span></li><li><span><a href="#Combined" data-toc-modified-id="Combined-6.4.5.4"><span class="toc-item-num">6.4.5.4&nbsp;&nbsp;</span>Combined</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Alpha diversity calculations using tree-based methods and non-tree-based methods

# %% [markdown]
# # Var

# %%
# working dir
work_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/'

# bracken counts
brk_file = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/bracken_filt.qs'

# metadata
## filtered
metadata_filt_file = file.path(work_dir, 'CurMetDat_metadata_filt-n1846.tsv')
## all 
base_in_dir = '/ebio/abt3_projects/small_projects/nyoungblut/public_data_retireval/'
metadata_file = file.path(base_in_dir, 'CurMetDat-metagenomes', 'files', 'metadata', 'Filtered_CurMetDat_f.tsv')

# ref genome metadata (GTDBr89 metadata)
genome_meta_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/metadata_1per-GTDB-Spec_gte50comp-lt5cont_wtaxID_wPath.tsv'

# metagenome profiling dir
profile_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP/'

# phylogeny
phy_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/phylogeny/ar122-bac120_r89_1per-GTDB-Spec_gte50comp-lt5cont_rn.nwk'
phy_trt_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG//phenotype/predictions_flat_majority-votes_combined_jaccard_rn.nwk'

# params
threads = 16

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(tidytable)
library(ape)
library(phyloseq)
library(vegan)
library(PhyloMeasures)
library(LeyLabRMisc)

# %%
make_dir(work_dir)
setDTthreads(threads)
df.dims()
# Out:
# Directory already exists: /ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/

# %% [markdown]
# # Load

# %% [markdown]
# ## Metadata

# %%
# all 
meta = fread(metadata_file, sep='\t', check.names=TRUE) %>%
    dt_mutate(Sample = gsub('-', '.', Sample)) %>%
    dt_filter(number_reads >= 5e5) %>%
    dt_select(Sample, dataset_name, subjectID, study_condition, 
              disease, age, gender, BMI, westernized)

meta %>% unique_n('Samples', Sample)
meta
# Out:
# No. of unique Samples: 3582
#      Sample              dataset_name  subjectID study_condition disease age
# 1    MV_FEM1_t1Q14       AsnicarF_2017 MV_FEM1   control         healthy NA
# 2    MV_FEM2_t1Q14       AsnicarF_2017 MV_FEM2   control         healthy NA
# ⋮    ⋮                   ⋮             ⋮         ⋮               ⋮       ⋮
# 3581 CCIS82944710ST.20.0 ZellerG_2014  FR-730    control         healthy 38
# 3582 CCIS93040568ST.20.0 ZellerG_2014  FR-682    control         healthy 65
#      gender BMI westernized
# 1    female NA  TRUE
# 2    female NA  TRUE
# ⋮    ⋮      ⋮   ⋮
# 3581 female 22  TRUE
# 3582 male   30  TRUE

# %%
# filtered metadata
meta_f = fread(metadata_filt_file, sep='\t') %>%
    dt_mutate(Sample = gsub('-', '.', Sample)) %>%
    dt_filter(number_reads >= 5e5) %>%
    dt_select(Sample, dataset, subjectID, study_condition, 
              disease, age, gender, BMI, westernized)

meta_f %>% unique_n('Samples', Sample)
meta_f
# Out:
# No. of unique Samples: 1802
#      Sample      dataset               subjectID     study_condition disease
# 1    TRAVELRES1  Bengtsson-PalmeJ_2015 TRAVELRES1_2  control         healthy
# 2    TRAVELRES10 Bengtsson-PalmeJ_2015 TRAVELRES9_10 control         healthy
# ⋮    ⋮           ⋮                     ⋮             ⋮               ⋮
# 4264 YEZ_N.38    YeZ_2018              YEZ_N-38      control         healthy
# 4265 YEZ_N.37    YeZ_2018              YEZ_N-37      control         healthy
#      age gender BMI  westernized
# 1    25  female NA   TRUE
# 2    34  female NA   TRUE
# ⋮    ⋮   ⋮      ⋮    ⋮
# 4264 38  female 19.7 TRUE
# 4265 46  male   29.7 TRUE

# %%
# genome metadata
tax_levs = c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species')
genome_meta = fread(genome_meta_file, sep='\t') %>%
    dt_select(ncbi_genbank_assembly_accession, ncbi_organism_name, gtdb_taxonomy, accession) %>%
    dt_rename('GTDB_accession' = accession) %>%
    dt_separate(gtdb_taxonomy, tax_levs, sep=';') %>%
    dt_mutate(Species = gsub(' ', '_', Species))

genome_meta %>% unique_n('accessions', ncbi_genbank_assembly_accession)
genome_meta
# Out:
# No. of unique accessions: 23360
#       ncbi_genbank_assembly_accession
# 1     GCA_002789635.1
# 2     GCA_001784635.1
# ⋮     ⋮
# 23359 GCA_001775395.1
# 23360 GCA_002791595.1
#       ncbi_organism_name
# 1     GB_GCA_002789635.1_Candidatus Aenigmarchaeota archaeon CG_4_9_14_3_um_filter_37_18
# 2     GB_GCA_001784635.1_Candidatus Micrarchaeota archaeon RBG_16_49_10
# ⋮     ⋮
# 23359 GB_GCA_001775395.1_candidate division Zixibacteria bacterium RBG_16_53_22
# 23360 GB_GCA_002791595.1_candidate division Zixibacteria bacterium CG_4_9_14_3_um_filter_46_8
#       GTDB_accession     Domain      Phylum             Class
# 1     GB_GCA_002789635.1 d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia
# 2     GB_GCA_001784635.1 d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia
# ⋮     ⋮                  ⋮           ⋮                  ⋮
# 23359 GB_GCA_001775395.1 d__Bacteria p__Zixibacteria    c__MSB-5A5
# 23360 GB_GCA_002791595.1 d__Bacteria p__Zixibacteria    c__MSB-5A5
# ...

# %% [markdown]
# ## Trees

# %%
# Genome phylogeny
gtdb_phy = read.tree(phy_file)
gtdb_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	s__Halorubrum_sp000296615, s__Halorubrum_distributum, s__Halorubrum_trapanicum, s__Halorubrum_tropicale, s__Halorubrum_coriense, s__Halorubrum_ezzemoulense, ...
# Node labels:
# 	100.0, d__Archaea100.0, 97.0, 99.0, 100.0, 100.0-p__Halobacterota, ...
#
# Rooted; includes branch lengths.

# %%
# traitar trait dendrogram
trt_phy = read.tree(phy_trt_file)
trt_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	s__Mikella_endobia, s__Prochlorococcus_B_sp003284185, s__Prochlorococcus_A_sp003282425, s__Eperythrozoon_A_wenyonii_A, s__GN02-872_sp003260325, s__SZUA-486_sp003251635, ...
#
# Rooted; includes branch lengths.

# %%
# checking key overlap
overlap(gtdb_phy$tip.label, trt_phy$tip.label)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %% [markdown]
# ## Bracken counts

# %%
# reading in bracken counts
brk_cls = qs::qread(brk_file, nthreads=threads) %>%
    as.data.table %>%
    dt_mutate(name = name %>% gsub(' ', '_', .))
brk_cls
# Out:
#         dataset       name                         taxonomy_id taxonomy_lvl
# 1       CosteaPI_2017 s__Caecibacter_massiliensis  108259      S
# 2       CosteaPI_2017 s__UBA1777_sp002350825       178550      S
# ⋮       ⋮             ⋮                            ⋮           ⋮
# 4934811 YuJ_2015      s__Serratia_grimesii         121568      S
# 4934812 YuJ_2015      s__Bacteroides_A_sp002161565 119189      S
#         Domain   Phylum         Class               Order
# 1       Bacteria Firmicutes_C   Negativicutes       Veillonellales
# 2       Bacteria Firmicutes_A   Clostridia          Oscillospirales
# ⋮       ⋮        ⋮              ⋮                   ⋮
# 4934811 Bacteria Proteobacteria Gammaproteobacteria Enterobacterales
# 4934812 Bacteria Bacteroidota   Bacteroidia         Bacteroidales
#         Family             Genus         Species
# 1       Megasphaeraceae    Caecibacter   Caecibacter massiliensis
# 2       Oscillospiraceae   UBA1777       UBA1777 sp002350825
# ...

# %%
# overlap with ref genome metadata
overlap(brk_cls, genome_meta, name, Species)
# Out:
# intersect(x,y): 3550
# setdiff(x,y): 0
# setdiff(y,x): 19810
# union(x,y): 23360

# %%
# overlap with sample IDs
overlap(brk_cls, meta, Sample, Sample)
# Out:
# intersect(x,y): 3348
# setdiff(x,y): 9
# setdiff(y,x): 234
# union(x,y): 3591

# %%
# overlap with sample IDs
overlap(brk_cls, meta_f, Sample, Sample)
# Out:
# intersect(x,y): 1799
# setdiff(x,y): 1558
# setdiff(y,x): 3
# union(x,y): 3360

# %%
# checking overlap with phylogeny tip labels
overlap(brk_cls, gtdb_phy$tip.label, name)
# Out:
# intersect(x,y): 3550
# setdiff(x,y): 0
# setdiff(y,x): 19810
# union(x,y): 23360

# %% [markdown]
# ### Summary

# %%
# summary
brk_cls %>% unique_n('taxa', name)
# Out:
# No. of unique taxa: 3550

# %%
# summary
brk_cls %>% unique_n('samples', Sample)
# Out:
# No. of unique samples: 3357

# %%
# summary
brk_cls %>% unique_n('samples', Phylum)
# Out:
# No. of unique samples: 37

# %% [markdown]
# # Alpha div calc
#
# * shannon => vegan
# * PD => phylomeasures (or picante)

# %% [markdown]
# ## Summary of taxonomic groups

# %%
overlap(brk_cls, meta_f, Sample, Sample)

brk_cls_j = brk_cls %>%
    dt_inner_join(meta_f, by=c('Sample', 'dataset'))

brk_cls_j %>% unique_n('Samples', Sample)
brk_cls_j %>% unique_n('Datasets', dataset)
brk_cls_j
# Out:
# intersect(x,y): 1799
# setdiff(x,y): 1558
# setdiff(y,x): 3
# union(x,y): 3360
# No. of unique Samples: 1799
# No. of unique Datasets: 17
#         dataset               name                         taxonomy_id
# 1       Bengtsson-PalmeJ_2015 s__An200_sp003268275         146203
# 2       Bengtsson-PalmeJ_2015 s__Prevotella_sp900107705    172643
# ⋮       ⋮                     ⋮                            ⋮
# 5839520 YeZ_2018              s__Gottschalkia_acidurici    167951
# 5839521 YeZ_2018              s__Bacteroides_A_sp002161565 119189
#         taxonomy_lvl Domain   Phylum       Class       Order
# 1       S            Bacteria Firmicutes_A Clostridia  Oscillospirales
# 2       S            Bacteria Bacteroidota Bacteroidia Bacteroidales
# ⋮       ⋮            ⋮        ⋮            ⋮           ⋮
# 5839520 S            Bacteria Firmicutes_A Clostridia  Tissierellales
# 5839521 S            Bacteria Bacteroidota Bacteroidia Bacteroidales
# ...

# %% [markdown]
# ### No. of phyla

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Abundance > 0) %>%
    dt_mutate(Taxonomy = paste(Domain, Phylum, sep=';')) %>%
    dt_summarize(n_clades = n_distinct(Taxonomy), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample      westernized age gender n_clades age_bin
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  westernized 25  female  9       >=20,<30
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 westernized 34  female 12       >=30,<40
# ⋮    ⋮                     ⋮           ⋮           ⋮   ⋮      ⋮        ⋮
# 1798 YeZ_2018              YEZ_N.38    westernized 38  female 7        >=30,<40
# 1799 YeZ_2018              YEZ_N.37    westernized 46  male   8        >=40,<50

# %%
p = brk_cls_j_s %>%
    ggplot(aes(age_bin, n_clades, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='No. of phyla') +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### No. of genera

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Abundance > 0) %>%
    dt_mutate(Taxonomy = paste(Domain, Phylum, Class, Order, Family, Genus, sep=';')) %>%
    dt_summarize(n_clades = n_distinct(Taxonomy), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample      westernized age gender n_clades age_bin
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  westernized 25  female 147      >=20,<30
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 westernized 34  female 160      >=30,<40
# ⋮    ⋮                     ⋮           ⋮           ⋮   ⋮      ⋮        ⋮
# 1798 YeZ_2018              YEZ_N.38    westernized 38  female 87       >=30,<40
# 1799 YeZ_2018              YEZ_N.37    westernized 46  male   52       >=40,<50

# %%
p = brk_cls_j_s %>%
    ggplot(aes(age_bin, n_clades, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='No. of genera') +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Treponema

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Family == 'Treponemataceae') %>%
    dt_summarize(Abundance = sum(Abundance), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset      Sample          westernized     age gender Abundance age_bin
# 1    BritoIL_2016 M1.23.ST        non-westernized 23  male   0.00000   >=20,<30
# 2    BritoIL_2016 M1.24.ST        non-westernized 24  male   0.38589   >=20,<30
# ⋮    ⋮            ⋮               ⋮               ⋮   ⋮      ⋮         ⋮
# 1296 XieH_2016    YSZC12003_37879 westernized     42  female 0         >=40,<50
# 1297 XieH_2016    YSZC12003_37880 westernized     42  female 0         >=40,<50

# %%
p = brk_cls_j_s %>%
    dt_mutate(Abundance = ifelse(Abundance == 0, 0.00001, Abundance)) %>%
    ggplot(aes(age_bin, Abundance, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='Treponemataceae\nAbundance (log10)') +
    scale_y_log10() +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.3)
plot(p)
# Out:
# plot without title

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Family == 'Treponemataceae') %>%
    dt_summarize(n_species = n_distinct(name), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset      Sample          westernized     age gender n_species age_bin
# 1    BritoIL_2016 M1.23.ST        non-westernized 23  male   28        >=20,<30
# 2    BritoIL_2016 M1.24.ST        non-westernized 24  male   28        >=20,<30
# ⋮    ⋮            ⋮               ⋮               ⋮   ⋮      ⋮         ⋮
# 1296 XieH_2016    YSZC12003_37879 westernized     42  female 1         >=40,<50
# 1297 XieH_2016    YSZC12003_37880 westernized     42  female 1         >=40,<50

# %%
p = brk_cls_j_s %>%
    ggplot(aes(age_bin, n_species, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='No. of Treponemataceae species') +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Methanogens

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(grepl('Methano|Thermo', Class),
              grepl('Methano', Order)) %>%
    dt_summarize(Abundance = sum(Abundance), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample      westernized age gender Abundance
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  westernized 25  female 0.00000
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 westernized 34  female 0.00028
# ⋮    ⋮                     ⋮           ⋮           ⋮   ⋮      ⋮
# 1798 YeZ_2018              YEZ_N.38    westernized 38  female 0
# 1799 YeZ_2018              YEZ_N.37    westernized 46  male   0
#      age_bin
# 1    >=20,<30
# 2    >=30,<40
# ⋮    ⋮
# 1798 >=30,<40
# 1799 >=40,<50

# %%
p = brk_cls_j_s %>%
    dt_mutate(Abundance = ifelse(Abundance == 0, 0.00001, Abundance)) %>%
    ggplot(aes(age_bin, Abundance, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='Methanogen\nAbundance (log10)') +
    scale_y_log10() +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.3)
plot(p)
# Out:
# plot without title

# %%
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Family == 'Methanobacteriaceae') %>%
    dt_summarize(Abundance = sum(Abundance), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample          westernized age gender Abundance
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1      westernized 25  female 0.00000
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10     westernized 34  female 0.00028
# ⋮    ⋮                     ⋮               ⋮           ⋮   ⋮      ⋮
# 1753 XieH_2016             YSZC12003_37879 westernized 42  female 0
# 1754 XieH_2016             YSZC12003_37880 westernized 42  female 0
#      age_bin
# 1    >=20,<30
# 2    >=30,<40
# ⋮    ⋮
# 1753 >=40,<50
# 1754 >=40,<50

# %%
p = brk_cls_j_s %>%
    dt_mutate(Abundance = ifelse(Abundance == 0, 0.00001, Abundance)) %>%
    ggplot(aes(age_bin, Abundance, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='Methanobacteriaceae\nAbundance (log10)') +
    scale_y_log10() +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.3)
plot(p)
# Out:
# plot without title

# %%
# no. of species
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Family == 'Methanobacteriaceae') %>%
    dt_summarize(n_species = n_distinct(name), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample          westernized age gender n_species
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1      westernized 25  female 3
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10     westernized 34  female 3
# ⋮    ⋮                     ⋮               ⋮           ⋮   ⋮      ⋮
# 1753 XieH_2016             YSZC12003_37879 westernized 42  female 8
# 1754 XieH_2016             YSZC12003_37880 westernized 42  female 8
#      age_bin
# 1    >=20,<30
# 2    >=30,<40
# ⋮    ⋮
# 1753 >=40,<50
# 1754 >=40,<50

# %%
p = brk_cls_j_s %>%
    ggplot(aes(age_bin, n_species, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='No. of Methanobacteriaceae species') +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Christ.

# %%
brk_cls_j_s = brk_cls_j %>%
     dt_filter(Family == 'Christensenellaceae') %>%
    dt_summarize(Abundance = sum(Abundance), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample          westernized age gender Abundance
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1      westernized 25  female 0
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10     westernized 34  female 0
# ⋮    ⋮                     ⋮               ⋮           ⋮   ⋮      ⋮
# 1560 XieH_2016             YSZC12003_37879 westernized 42  female 0
# 1561 XieH_2016             YSZC12003_37880 westernized 42  female 0
#      age_bin
# 1    >=20,<30
# 2    >=30,<40
# ⋮    ⋮
# 1560 >=40,<50
# 1561 >=40,<50

# %%
p = brk_cls_j_s %>%
    dt_mutate(Abundance = ifelse(Abundance == 0, 0.00001, Abundance)) %>%
    ggplot(aes(age_bin, Abundance, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='Christensenellaceae\nAbundance (log10)') +
    scale_y_log10() +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.3)
plot(p)
# Out:
# plot without title

# %%
# no. of species
brk_cls_j_s = brk_cls_j %>%
    dt_filter(Family == 'Christensenellaceae') %>%
    dt_summarize(n_species = n_distinct(name), 
                 by=c(dataset, Sample, westernized, age, gender)) %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'))

brk_cls_j_s
# Out:
#      dataset               Sample          westernized age gender n_species
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1      westernized 25  female 2
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10     westernized 34  female 2
# ⋮    ⋮                     ⋮               ⋮           ⋮   ⋮      ⋮
# 1560 XieH_2016             YSZC12003_37879 westernized 42  female 5
# 1561 XieH_2016             YSZC12003_37880 westernized 42  female 5
#      age_bin
# 1    >=20,<30
# 2    >=30,<40
# ⋮    ⋮
# 1560 >=40,<50
# 1561 >=40,<50

# %%
p = brk_cls_j_s %>%
    ggplot(aes(age_bin, n_species, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='No. of Christensenellaceae species') +
    scale_color_discrete('') +
    facet_grid(gender ~ .) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(5,3.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Formatting
#
# * creating `sample * species` matrix for vegan & phylomeasures

# %%
# making matrix 
brk_cls_w = brk_cls %>%
    #dt_slice_head(100000) %>%   # debug
    dt_select(name, Abundance, Sample) %>%
    dt_pivot_wider(id_cols=Sample, names_from=name, values_from=Abundance) %>%
    as_tibble %>%
    mutate_if(is.numeric, function(x) ifelse(is.na(x), 0, x)) %>%
    as.data.frame

rownames(brk_cls_w) = brk_cls_w$Sample
brk_cls_w$Sample = NULL

brk_cls_w
# Out:
#                   s__1-14-0-10-34-76_sp002763075 s__1-19_sp001922585
# A01_02_1FE        0                              0
# A02_01_1FE        0                              0
# ⋮                 ⋮                              ⋮
# nHMX11726         0                              0
# scavenger.11.60.0 0                              0
#                   s__14-2_sp000403255 s__14-2_sp000403315 s__14-2_sp000403845
# A01_02_1FE        0                   0                   0
# A02_01_1FE        0                   0                   0
# ⋮                 ⋮                   ⋮                   ⋮
# nHMX11726         0                   0                   0
# scavenger.11.60.0 0                   0                   0
#                   s__14-2_sp001940225 s__2-01-FULL-39-21_sp001792305
# A01_02_1FE        0                   0
# A02_01_1FE        0                   0
# ⋮                 ⋮                   ⋮
# nHMX11726         0e+00               0
# ...

# %%
# checking overlap
overlap(colnames(brk_cls_w), gtdb_phy$tip.label)
# Out:
# intersect(x,y): 3550
# setdiff(x,y): 0
# setdiff(y,x): 19810
# union(x,y): 23360

# %%
# wrapper for calculating Faith's PD
calc_pd = function(tree, df){
    df %>% 
        apply(2, function(x) ifelse(is.na(x) | x <= 0, 0, 1)) %>%
        PhyloMeasures::pd.query(tree, ., standardize = FALSE, null.model="uniform", 
                                reps=100, seed=3982)
}

# %%
# calculating alpha diversity for all samples
alpha_div = data.frame(
    Sample = rownames(brk_cls_w),
    nobs = brk_cls_w %>% apply(1, function(x) sum(x > 0)) %>% as.vector,
    shannon = vegan::diversity(brk_cls_w) %>% as.vector,
    pd_phy = calc_pd(gtdb_phy, brk_cls_w) %>% as.vector,  # phylogeny
    pd_trt = calc_pd(trt_phy, brk_cls_w) %>% as.vector    # traits
)

alpha_div
# Out:
#      Sample            nobs shannon  pd_phy   pd_trt
# 1    A01_02_1FE        232  3.888802 55.94272 43.94092
# 2    A02_01_1FE        176  3.418777 40.24502 31.18437
# ⋮    ⋮                 ⋮    ⋮        ⋮        ⋮
# 3356 nHMX11726         272  3.612832 53.11264 46.47031
# 3357 scavenger.11.60.0 210  3.891553 37.27697 35.63946

# %% [markdown]
# # Alpha div summary

# %%
# writing table
alpha_div_file = file.path(work_dir, 'alpha_div.tsv')
write_table(alpha_div, alpha_div_file)
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity//alpha_div.tsv

# %%
# checking key overlap
overlap(alpha_div, meta, Sample, Sample)
# Out:
# intersect(x,y): 0
# setdiff(x,y): 3357
# setdiff(y,x): 9
# union(x,y): 3366

# %%
# formatting and adding metadata
alpha_div = alpha_div %>%
    as.data.table %>%
    dt_pivot_longer(cols = -Sample, names_to=c('Metric'), values_to=c('Metric_value')) %>%
    dt_inner_join(meta, by=c('Sample')) 
alpha_div
# Out:
# Warning message in melt.data.table(data = .data, id.vars = id_vars, measure.vars = cols, :
# “'measure.vars' [nobs, shannon, pd_phy, pd_trt] are not all of the same type. By order of hierarchy, the molten data value column will be of type 'double'. All measure variables not of type 'double' will be coerced too. Check DETAILS in ?melt.data.table for more on coercion.”
#       Sample            Metric  Metric_value dataset_name  subjectID
# 1     MV_FEM1_t1Q14     nobs    242.00000    AsnicarF_2017 MV_FEM1
# 2     MV_FEM1_t1Q14     shannon   2.73179    AsnicarF_2017 MV_FEM1
# ⋮     ⋮                 ⋮       ⋮            ⋮             ⋮
# 13391 PNP_Validation_46 pd_phy  51.18093     ZeeviD_2015   PNP_Validation_46
# 13392 PNP_Validation_46 pd_trt  37.87113     ZeeviD_2015   PNP_Validation_46
#       study_condition disease age gender BMI westernized
# 1     control         healthy NA  female NA  TRUE
# 2     control         healthy NA  female NA  TRUE
# ...

# %%
# checking number of samples
brk_cls %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('Samples', Sample)

brk_cls %>% unique_n('datasets', dataset)
alpha_div %>% unique_n('datasets', dataset_name)
# Out:
# No. of unique Samples: 3357
# No. of unique Samples: 3348
# No. of unique datasets: 33
# No. of unique datasets: 33

# %%
# summarizing
alpha_div_s = alpha_div %>%
    dt_mutate(sum_div = mean(ifelse(Metric == 'nobs', Metric_value, 0)), 
              by=c(dataset_name)) %>%
    dt_mutate(Metric = dt_case(Metric == 'nobs', 'No. observed',
                               Metric == 'shannon', 'Shannon',
                               Metric == 'pd_phy', 'Faith\'s PD (phy)',
                               Metric == 'pd_trt', 'Faith\'s PD (trt)') ) %>%
    dt_mutate(dataset_name = reorder(dataset_name, -sum_div))

alpha_div_s
# Out:
#       Sample            Metric           Metric_value dataset_name
# 1     MV_FEM1_t1Q14     No. observed     242.00000    AsnicarF_2017
# 2     MV_FEM1_t1Q14     Shannon            2.73179    AsnicarF_2017
# ⋮     ⋮                 ⋮                ⋮            ⋮
# 13391 PNP_Validation_46 Faith's PD (phy) 51.18093     ZeeviD_2015
# 13392 PNP_Validation_46 Faith's PD (trt) 37.87113     ZeeviD_2015
#       subjectID         study_condition disease age gender BMI westernized
# 1     MV_FEM1           control         healthy NA  female NA  TRUE
# 2     MV_FEM1           control         healthy NA  female NA  TRUE
# ⋮     ⋮                 ⋮               ⋮       ⋮   ⋮      ⋮   ⋮
# 13391 PNP_Validation_46 control         healthy NA  NA     NA  TRUE
# 13392 PNP_Validation_46 control         healthy NA  NA     NA  TRUE
#       sum_div
# 1     71.8125
# 2     71.8125
# ⋮     ⋮
# 13391 73.84585
# 13392 73.84585

# %%
# plotting by study
p = alpha_div_s %>%
    ggplot(aes(dataset_name, Metric_value)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Dataset', y='Alpha diversity') +
    facet_grid(Metric ~ ., scales='free_y') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(7,5.6)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Westernized

# %%
# plotting
alpha_div_s %>% dt_filter(!is.na(westernized)) %>% unique_n('Samples', Sample)
alpha_div_s %>% dt_filter(!is.na(westernized)) %>% unique_n('datasets', dataset_name)

p = alpha_div_s %>%
    dt_mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized')) %>%
    ggplot(aes(dataset_name, Metric_value, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('') +
    labs(x='Dataset', y='Alpha diversity') +
    facet_grid(Metric ~ ., scales='free_y') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(7,5.6)
plot(p)
# Out:
# No. of unique Samples: 3348
# No. of unique datasets: 33
# plot without title

# %%
levs = c('No. observed', 'Shannon', 'Faith\'s PD (phy)', 'Faith\'s PD (trt)')
p = alpha_div_s %>%
    dt_mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'),
              Metric = Metric %>% factor(levels = levs)) %>%
    ggplot(aes(westernized, Metric_value)) +
    geom_boxplot(outlier.size = 0.5, notch=TRUE) +
    #geom_jitter(height=0, aes(color=dataset_name), shape='O', alpha=0.2) +
    labs(x='Dataset', y='Alpha diversity') +
    facet_wrap(. ~ Metric, scales='free_y', nrow=1) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1),
        legend.position = 'none'
    )

p.dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Age

# %%
x = alpha_div_s %>%
    dt_filter(!is.na(age),
              !is.na(gender))
x %>% unique_n('No. of samples', Sample)

p = x %>%
    dt_mutate(Metric = Metric %>% factor(levels = levs)) %>%
    ggplot(aes(age, Metric_value, color=gender)) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.5, shape='O') +
    labs(x='Dataset', y='Alpha diversity') +
    facet_wrap(. ~ Metric, scales='free_y', nrow=1) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(9,3)
plot(p)
# Out:
# No. of unique No. of samples: 1843
# plot without title

# %%
# age, gender, and westernization
x = alpha_div_s %>%
    dt_filter(!is.na(age),
              !is.na(gender))
x %>% unique_n('No. of samples', Sample)

p = x %>%
    as_tibble %>%
    mutate(age_bin = case_when(age < 10 ~ '<10',
                               age >= 10 & age < 20 ~ '>=10,<20',
                               age >= 20 & age < 30 ~ '>=20,<30',
                               age >= 30 & age < 40 ~ '>=30,<40',
                               age >= 40 & age < 50 ~ '>=40,<50',
                               age >= 50 & age < 60 ~ '>=50,<60',
                               age >= 60 & age < 70 ~ '>=60,<70',
                               age >= 70 & age < 80 ~ '>=70,<80',
                               age >= 80 ~ '>=80')) %>%
    mutate(Metric = Metric %>% factor(levels = levs),
           westernized = ifelse(westernized, 'westernized', 'non-westernized')) %>%
    ggplot(aes(age_bin, Metric_value, color=westernized)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Age bin', y='Alpha diversity') +
    scale_color_discrete('') +
    facet_wrap(gender ~ Metric, scales='free_y', nrow=2) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1),
        strip.text = element_text(margin = margin(0,0,0,0, "cm"))
    )

p.dims(9,4)
plot(p)
# Out:
# No. of unique No. of samples: 1843
# plot without title

# %% [markdown]
# ### Study condition & disease

# %%
# studies per disease
df.dims(30)
alpha_div_s %>%
    dt_summarize(n_datasets = n_distinct(dataset_name),
                 by = c(disease)) %>%
    dt_arrange(-n_datasets)
df.dims()
# Out:
#    disease                          n_datasets
# 1  healthy                          21
# 2  NA                                7
# 3  fatty_liver                       2
# 4  hypertension                      2
# 5  melanoma;metastases               2
# 6  fatty_liver;hypertension          1
# 7  fatty_liver;T2D;hypertension      1
# 8  T2D;hypertension                  1
# 9  fatty_liver;T2D                   1
# 10 coeliac;gestational_diabetes;CMV  1
# 11 hepatitis                         1
# 12 ACVD                              1
# 13 IGT                               1
# 14 T2D                               1
# 15 metabolic_syndrome                1
# 16 STEC                              1

# %%
# samples per disease
df.dims(30)
alpha_div_s %>%
    dt_summarize(n_samples = n_distinct(Sample),
                 by = c(disease)) %>%
    dt_arrange(-n_samples)
df.dims()
# Out:
#    disease                          n_samples
# 1  healthy                          2102
# 2  NA                                593
# 3  ACVD                              214
# 4  hypertension                      163
# 5  melanoma;metastases                64
# 6  T2D                                53
# 7  IGT                                49
# 8  fatty_liver                        38
# 9  STEC                               38
# 10 fatty_liver;hypertension           13
# 11 fatty_liver;T2D;hypertension        9
# 12 fatty_liver;T2D                     3
# 13 hepatitis                           3
# 14 metabolic_syndrome                  3
# 15 coeliac;gestational_diabetes;CMV    2
# 16 T2D;hypertension                    1

# %%
# plotting
p = alpha_div_s %>%
    ggplot(aes(dataset_name, Metric_value, color=study_condition)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Dataset', y='Alpha diversity') +
    facet_grid(Metric ~ ., scales='free_y') +
    scale_color_discrete('Study\ncondition') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1, size=8)
    )

p.dims(7,5.6)
plot(p)
# Out:
# plot without title

# %%
# plotting
p = alpha_div_s %>%
    ggplot(aes(dataset_name, Metric_value, color=disease)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Disease') +
    labs(x='Dataset', y='Alpha diversity') +
    facet_grid(Metric ~ ., scales='free_y') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1, size=8)
    )

p.dims(8,5.6)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## ANOVA: full dataset

# %% [markdown]
# ### Westernized

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    aov(Metric_value ~ westernized + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# westernized     1  26857   26857   220.8 <2e-16 ***
# dataset_name   32 165417    5169    42.5 <2e-16 ***
# Residuals    3314 403071     122
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    aov(Metric_value ~ westernized + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value   Pr(>F)
# westernized     1   5248    5248   64.04 1.67e-15 ***
# dataset_name   32 151370    4730   57.72  < 2e-16 ***
# Residuals    3314 271604      82
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    aov(Metric_value ~ westernized + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# westernized     1    1.3   1.277   5.344 0.0209 *
# dataset_name   32  498.7  15.585  65.201 <2e-16 ***
# Residuals    3314  792.2   0.239
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Study condition

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    aov(Metric_value ~ study_condition + dataset_name, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value Pr(>F)
# study_condition    9  59723    6636   54.48 <2e-16 ***
# dataset_name      28 132444    4730   38.83 <2e-16 ***
# Residuals       3310 403178     122
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    aov(Metric_value ~ study_condition + dataset_name, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value Pr(>F)
# study_condition    9  41193    4577   55.92 <2e-16 ***
# dataset_name      28 116102    4146   50.66 <2e-16 ***
# Residuals       3310 270927      82
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    aov(Metric_value ~ study_condition + dataset_name, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value Pr(>F)
# study_condition    9  151.3  16.806   70.47 <2e-16 ***
# dataset_name      28  351.6  12.556   52.65 <2e-16 ***
# Residuals       3310  789.3   0.238
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Disease

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# disease        14  49340    3524   28.77 <2e-16 ***
# dataset_name   23 100611    4374   35.71 <2e-16 ***
# Residuals    2717 332865     123
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# disease        14  34301    2450   29.46 <2e-16 ***
# dataset_name   23  91314    3970   47.73 <2e-16 ***
# Residuals    2717 225983      83
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# disease        14  138.9   9.921   40.26 <2e-16 ***
# dataset_name   23  331.4  14.409   58.48 <2e-16 ***
# Residuals    2717  669.5   0.246
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## ANOVA: filtered

# %%
# filtering
alpha_div_f = alpha_div %>%
    dt_filter(!is.na(study_condition),
              !is.na(gender),
              !is.na(age))

alpha_div %>% unique_n('Samples', Sample)
alpha_div_f %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('datasets', dataset_name)
alpha_div_f %>% unique_n('datasets', dataset_name)
# Out:
# No. of unique Samples: 3348
# No. of unique Samples: 1843
# No. of unique datasets: 33
# No. of unique datasets: 17

# %% [markdown]
# ### Westernized

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    aov(Metric_value ~ westernized + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value   Pr(>F)
# westernized     1  17637   17637 151.388  < 2e-16 ***
# dataset_name   16  81360    5085  43.646  < 2e-16 ***
# gender          1    713     713   6.116   0.0135 *
# age             1   2292    2292  19.672 9.74e-06 ***
# Residuals    1823 212389     117
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    aov(Metric_value ~ westernized * gender + dataset_name + age, data=.) %>% 
    summary
# Out:
#                      Df Sum Sq Mean Sq F value   Pr(>F)
# westernized           1  17637   17637 151.542  < 2e-16 ***
# gender                1  15835   15835 136.056  < 2e-16 ***
# dataset_name         16  66238    4140  35.570  < 2e-16 ***
# age                   1   2292    2292  19.692 9.64e-06 ***
# westernized:gender    1    332     332   2.856   0.0912 .
# Residuals          1822 212056     116
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    aov(Metric_value ~ westernized + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value   Pr(>F)
# westernized     1   2619    2619  34.803 4.34e-09 ***
# dataset_name   16  85679    5355  71.156  < 2e-16 ***
# gender          1    626     626   8.315 0.003979 **
# age             1   1139    1139  15.136 0.000104 ***
# Residuals    1823 137193      75
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    aov(Metric_value ~ westernized * gender + dataset_name + age, data=.) %>% 
    summary
# Out:
#                      Df Sum Sq Mean Sq F value   Pr(>F)
# westernized           1   2619    2619  34.833 4.27e-09 ***
# gender                1  11624   11624 154.598  < 2e-16 ***
# dataset_name         16  74681    4668  62.076  < 2e-16 ***
# age                   1   1139    1139  15.149 0.000103 ***
# westernized:gender    1    196     196   2.607 0.106538
# Residuals          1822 136997      75
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    aov(Metric_value ~ westernized + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value   Pr(>F)
# westernized     1    0.2   0.245   1.142 0.285438
# dataset_name   16  255.2  15.952  74.444  < 2e-16 ***
# gender          1    0.7   0.716   3.340 0.067769 .
# age             1    3.1   3.113  14.529 0.000143 ***
# Residuals    1823  390.6   0.214
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Study condition

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    aov(Metric_value ~ study_condition + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value   Pr(>F)
# study_condition    3   8727    2909  24.641 1.26e-15 ***
# dataset_name      16  87182    5449  46.154  < 2e-16 ***
# gender             1   1061    1061   8.986  0.00276 **
# age                1   2438    2438  20.650 5.88e-06 ***
# Residuals       1821 214983     118
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    aov(Metric_value ~ study_condition + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value   Pr(>F)
# study_condition    3   7529    2510   33.25  < 2e-16 ***
# dataset_name      16  80210    5013   66.42  < 2e-16 ***
# gender             1    848     848   11.24 0.000817 ***
# age                1   1216    1216   16.11 6.22e-05 ***
# Residuals       1821 137452      75
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    aov(Metric_value ~ study_condition + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                   Df Sum Sq Mean Sq F value   Pr(>F)
# study_condition    3   17.0   5.672   26.52  < 2e-16 ***
# dataset_name      16  239.2  14.952   69.91  < 2e-16 ***
# gender             1    1.0   1.007    4.71   0.0301 *
# age                1    3.3   3.280   15.34 9.33e-05 ***
# Residuals       1821  389.4   0.214
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Disease

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value   Pr(>F)
# disease        11  11538    1049   8.928 1.59e-15 ***
# dataset_name   11  50662    4606  39.203  < 2e-16 ***
# gender          1    818     818   6.960 0.008428 **
# age             1   1777    1777  15.129 0.000105 ***
# Residuals    1388 163064     117
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value  Pr(>F)
# disease        11  11079    1007  13.085 < 2e-16 ***
# dataset_name   11  51319    4665  60.611 < 2e-16 ***
# gender          1    635     635   8.253 0.00413 **
# age             1    828     828  10.761 0.00106 **
# Residuals    1388 106836      77
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    dt_filter(!is.na(disease)) %>%
    aov(Metric_value ~ disease + dataset_name + gender + age, data=.) %>% 
    summary
# Out:
#                Df Sum Sq Mean Sq F value  Pr(>F)
# disease        11  27.95   2.541  11.492 < 2e-16 ***
# dataset_name   11 202.67  18.425  83.326 < 2e-16 ***
# gender          1   0.65   0.651   2.944 0.08642 .
# age             1   2.17   2.172   9.822 0.00176 **
# Residuals    1388 306.91   0.221
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## lmer: full dataset

# %%
library(lme4)
library(lmerTest)
# Out:
# Warning message:
# “package ‘lme4’ was built under R version 3.6.3”
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %% [markdown]
# ### Westernized

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 25668.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.6556 -0.6645 -0.0168  0.6620  4.2644
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  41.89    6.472
#  Residual                 121.60   11.027
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                 Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)       58.272      1.685  78.204  34.584  < 2e-16 ***
# westernizedTRUE   -7.512      1.589 331.406  -4.728 3.35e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.718
#             Sum Sq   Mean Sq  NumDF DenDF    F value  Pr(>F)
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 24359
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8763 -0.6286  0.0315  0.6675  4.2248
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 41.16    6.416
#  Residual                 81.94    9.052
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                 Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)       49.012      1.552  75.660  31.584  < 2e-16 ***
# westernizedTRUE   -3.771      1.368 534.451  -2.757  0.00603 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.672
#             Sum Sq   Mean Sq  NumDF DenDF    F value Pr(>F)
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 4828.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0963 -0.5280  0.1397  0.6716  2.8939
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1235   0.3514
#  Residual                 0.2390   0.4889
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)       3.96807    0.08455  75.26443  46.934   <2e-16 ***
# westernizedTRUE  -0.12259    0.07410 553.98939  -1.654   0.0986 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.668
#             Sum Sq    Mean Sq   NumDF DenDF    F value Pr(>F)
# ...

# %% [markdown]
# #### Westernized * gender

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    lmer(Metric_value ~ westernized * gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized * gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 16444.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.7667 -0.6778 -0.0168  0.6670  4.3880
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  58.08    7.621
#  Residual                 118.20   10.872
# Number of obs: 2154, groups:  dataset_name, 19
#
# Fixed effects:
#                             Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)                  66.6219     3.1125   27.7286  21.404  < 2e-16 ***
# westernizedTRUE             -16.3992     3.2877   46.6928  -4.988 8.88e-06 ***
# gendermale                    0.1715     1.1689 2136.6107   0.147    0.883
# westernizedTRUE:gendermale   -1.5638     1.3126 2138.5329  -1.191    0.234
# ---
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    lmer(Metric_value ~ westernized * gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized * gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 15517.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1056 -0.6460  0.0349  0.6826  3.2698
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 52.36    7.236
#  Residual                 76.61    8.752
# Number of obs: 2154, groups:  dataset_name, 19
#
# Fixed effects:
#                              Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)                  54.61661    2.78709   37.17011  19.596  < 2e-16
# westernizedTRUE              -9.35494    2.86109   77.40386  -3.270  0.00161
# gendermale                   -0.05939    0.94126 2138.49462  -0.063  0.94970
# westernizedTRUE:gendermale   -1.13910    1.05703 2139.14388  -1.078  0.28131
#
# (Intercept)                ***
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    lmer(Metric_value ~ westernized * gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized * gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 2912.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.3992 -0.5301  0.1256  0.6645  2.5325
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1352   0.3677
#  Residual                 0.2179   0.4668
# Number of obs: 2154, groups:  dataset_name, 19
#
# Fixed effects:
#                              Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)                   4.09980    0.14413   40.20446  28.446   <2e-16
# westernizedTRUE              -0.19849    0.14932   77.88617  -1.329    0.188
# gendermale                    0.03354    0.05020 2139.80619   0.668    0.504
# westernizedTRUE:gendermale   -0.08080    0.05637 2140.60873  -1.433    0.152
#
# (Intercept)                ***
# westernizedTRUE
# ...

# %% [markdown]
# ### study condition

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    lmer(Metric_value ~ study_condition + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 25619.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.6603 -0.6685 -0.0112  0.6595  4.2680
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  46.3     6.804
#  Residual                 121.4    11.019
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)                       59.4691     2.1631  132.0533  27.492  < 2e-16
# study_conditioncontrol            -0.7864     1.2652 3321.2757  -0.622   0.5343
# study_conditionfatty_liver        -3.3003     7.3111   30.7558  -0.451   0.6549
# study_conditionFMT                -1.0599     9.4998   87.2219  -0.112   0.9114
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    lmer(Metric_value ~ study_condition + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 24309.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8828 -0.6203  0.0358  0.6618  4.2272
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 44.90    6.701
#  Residual                 81.76    9.042
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)                       50.2303     1.9297  109.0458  26.030  < 2e-16
# study_conditioncontrol            -0.9068     1.0404 3335.7915  -0.872  0.38348
# study_conditionfatty_liver        -2.7185     7.0875   30.2444  -0.384  0.70398
# study_conditionFMT                 2.2945     8.6607   67.2568   0.265  0.79187
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    lmer(Metric_value ~ study_condition + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 4829.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1417 -0.5280  0.1381  0.6692  2.9648
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1291   0.3593
#  Residual                 0.2384   0.4883
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                                   Estimate Std. Error         df t value
# (Intercept)                        4.04132    0.10385  110.18093  38.914
# study_conditioncontrol            -0.05411    0.05618 3335.58675  -0.963
# study_conditionfatty_liver        -0.20380    0.38026   30.33798  -0.536
# study_conditionFMT                 0.23290    0.46567   68.04082   0.500
# study_conditionhypertension       -0.29138    0.10551 3228.33714  -2.762
# ...

# %% [markdown]
# ### Disease

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_phy',
              !is.na(disease)) %>%
    lmer(Metric_value ~ disease + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Correlation matrix not shown by default, as p = 16 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ disease + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 21033.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.6597 -0.6734 -0.0443  0.6606  4.2773
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  50.07    7.076
#  Residual                 121.27   11.012
# Number of obs: 2755, groups:  dataset_name, 29
#
# Fixed effects:
#                                          Estimate Std. Error        df t value
# (Intercept)                               64.3325     2.7960   53.3335  23.009
# diseasecoeliac;gestational_diabetes;CMV   -5.5639    10.7320   78.1948  -0.518
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'pd_trt',
              !is.na(disease)) %>%
    lmer(Metric_value ~ disease + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0031163 (tol = 0.002, component 1)”
#
# Correlation matrix not shown by default, as p = 16 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ disease + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 19995.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8495 -0.6267  0.0161  0.6658  4.2003
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 45.90    6.775
#  Residual                 82.81    9.100
# Number of obs: 2755, groups:  dataset_name, 29
#
# Fixed effects:
#                                          Estimate Std. Error        df t value
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'shannon',
              !is.na(disease)) %>%
    lmer(Metric_value ~ disease + westernized + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Correlation matrix not shown by default, as p = 16 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ disease + westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 4059.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0590 -0.5310  0.1327  0.6666  2.9510
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1318   0.3630
#  Residual                 0.2463   0.4963
# Number of obs: 2755, groups:  dataset_name, 29
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                                4.05297    0.13544   64.90302
# diseasecoeliac;gestational_diabetes;CMV   -0.37004    0.51525   75.10936
# diseasefatty_liver                        -0.34008    0.23571  159.04393
# ...

# %% [markdown]
# #### Simplified

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_phy',
              !is.na(disease),
              study_condition != 'control') %>%
    summary
# Out:
#     Sample             Metric           Metric_value   dataset_name
#  Length:609         Length:609         Min.   :15.87   Length:609
#  Class :character   Class :character   1st Qu.:37.76   Class :character
#  Mode  :character   Mode  :character   Median :45.29   Mode  :character
#                                        Mean   :47.02
#                                        3rd Qu.:55.66
#                                        Max.   :93.61
#
#   subjectID         study_condition      disease               age
#  Length:609         Length:609         Length:609         Min.   :35.00
#  Class :character   Class :character   Class :character   1st Qu.:61.00
#  Mode  :character   Mode  :character   Mode  :character   Median :69.00
#                                                           Mean   :65.55
#                                                           3rd Qu.:70.00
#                                                           Max.   :79.00
# ...

# %%
alpha_div %>%
    dt_filter(Metric == 'pd_trt',
              !is.na(disease),
              study_condition != 'control') %>%
    summary
# Out:
#     Sample             Metric           Metric_value   dataset_name
#  Length:609         Length:609         Min.   :10.19   Length:609
#  Class :character   Class :character   1st Qu.:34.11   Class :character
#  Mode  :character   Mode  :character   Median :42.69   Mode  :character
#                                        Mean   :42.95
#                                        3rd Qu.:51.59
#                                        Max.   :83.86
#
#   subjectID         study_condition      disease               age
#  Length:609         Length:609         Length:609         Min.   :35.00
#  Class :character   Class :character   Class :character   1st Qu.:61.00
#  Mode  :character   Mode  :character   Mode  :character   Median :69.00
#                                                           Mean   :65.55
#                                                           3rd Qu.:70.00
#                                                           Max.   :79.00
# ...

# %%
fm = alpha_div %>%
    dt_filter(Metric == 'shannon',
              !is.na(disease),
              study_condition != 'control') %>%
    lmer(Metric_value ~ disease + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ disease + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 1047.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.4538 -0.5644  0.1393  0.6912  2.6099
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.008056 0.08975
#  Residual                 0.317772 0.56371
# Number of obs: 609, groups:  dataset_name, 8
#
# Fixed effects:
#                            Estimate Std. Error       df t value Pr(>|t|)
# (Intercept)                 3.87560    0.09768  0.26629  39.678    0.268
# diseasefatty_liver         -0.15124    0.16500  0.54226  -0.917    0.611
# diseasehypertension        -0.72471    0.14017  0.28230  -5.170    0.444
# diseaseIGT                  0.56930    0.15518  0.42421   3.669    0.377
# diseasemelanoma;metastases -0.27108    0.13654  0.44741  -1.985    0.473
# ...

# %% [markdown]
# ## lmer: filtered

# %%
# filtering
alpha_div_f = alpha_div %>%
    dt_filter(!is.na(study_condition),
              !is.na(gender),
              !is.na(age)) %>%
    dt_mutate(age = log2(age))

alpha_div %>% unique_n('Samples', Sample)
alpha_div_f %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('datasets', dataset_name)
alpha_div_f %>% unique_n('datasets', dataset_name)
# Out:
# No. of unique Samples: 3348
# No. of unique Samples: 1843
# No. of unique datasets: 33
# No. of unique datasets: 17

# %%
alpha_div_f %>% 
    dt_select(study_condition, disease, age, gender, BMI, westernized) %>%
    dt_mutate(gender = gender %>% as.factor,
              study_condition = study_condition %>% as.factor,
              disease = disease %>% as.factor) %>%
    summary
# Out:
#  study_condition                     disease          age           gender
#  ACVD   : 368    healthy                 :4700   Min.   :4.248   female:4588
#  control:6596    ACVD                    : 368   1st Qu.:4.644   male  :2784
#  IGT    : 196    T2D                     : 212   Median :5.426
#  T2D    : 212    IGT                     : 196   Mean   :5.321
#                  fatty_liver;hypertension:  52   3rd Qu.:5.954
#                  (Other)                 : 124   Max.   :6.741
#                  NA's                    :1720
#       BMI        westernized
#  Min.   :16.02   Mode :logical
#  1st Qu.:20.90   FALSE:1420
#  Median :22.86   TRUE :5952
#  Mean   :23.66
#  3rd Qu.:25.40
#  Max.   :65.75
#  NA's   :3632

# %% [markdown]
# ### Westernized

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0022742 (tol = 0.002, component 1)”
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 14048.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.9397 -0.6655 -0.0208  0.6556  4.3082
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  55.26    7.434
#  Residual                 116.76   10.806
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                 Estimate Std. Error       df t value Pr(>|t|)
# (Intercept)       40.403      6.482  303.287   6.233 1.53e-09 ***
# westernizedTRUE  -16.923      3.229   38.309  -5.241 6.10e-06 ***
# age               11.014      2.379 1700.829   4.630 3.93e-06 ***
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 13246.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.2082 -0.6477  0.0422  0.6716  3.0688
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 50.01    7.072
#  Residual                 75.28    8.676
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)       35.6056     5.3700  325.3423   6.630 1.39e-10 ***
# westernizedTRUE   -9.7507     2.8161   65.4441  -3.462 0.000948 ***
# age                7.9558     1.9184 1794.1106   4.147 3.52e-05 ***
# gendermale        -1.5232     0.4661 1834.4684  -3.268 0.001103 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 2464.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9020 -0.5553  0.1150  0.6668  2.6166
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1325   0.3640
#  Residual                 0.2142   0.4628
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                   Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)        3.11809    0.28449  363.60829  10.960  < 2e-16 ***
# westernizedTRUE   -0.22529    0.14777   67.37902  -1.525   0.1320
# age                0.41668    0.10224 1788.95384   4.075 4.79e-05 ***
# gendermale        -0.05357    0.02486 1835.33426  -2.155   0.0313 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %% [markdown]
#  ### Study condition

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ study_condition + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + age + gender +
#     (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 14030.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.9612 -0.6790 -0.0243  0.6592  4.3219
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  61.69    7.854
#  Residual                 116.30   10.784
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                         Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)              42.9337     6.6816  327.8017   6.426 4.63e-10 ***
# study_conditioncontrol   -2.3708     1.5259 1835.5280  -1.554  0.12042
# study_conditionIGT       -5.5900     2.7023 1816.7718  -2.069  0.03872 *
# study_conditionT2D       -7.8344     2.6689 1814.7651  -2.935  0.00337 **
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ study_condition + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + age + gender +
#     (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 13228.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.2294 -0.6373  0.0446  0.6668  3.0684
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 53.27    7.299
#  Residual                 74.97    8.658
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                         Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)              37.8282     5.5057  347.1484   6.871 2.97e-11 ***
# study_conditioncontrol   -2.2956     1.2262 1833.7274  -1.872 0.061346 .
# study_conditionIGT       -3.8928     2.1740 1832.2489  -1.791 0.073527 .
# study_conditionT2D       -6.5776     2.1473 1831.6355  -3.063 0.002222 **
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ study_condition + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ study_condition + westernized + age + gender +
#     (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 2467.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9002 -0.5548  0.1118  0.6574  2.6281
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1386   0.3723
#  Residual                 0.2137   0.4622
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                          Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               3.22947    0.29149  390.78077  11.079  < 2e-16 ***
# study_conditioncontrol   -0.12140    0.06544 1834.57055  -1.855   0.0638 .
# study_conditionIGT       -0.20892    0.11599 1830.32319  -1.801   0.0718 .
# study_conditionT2D       -0.29210    0.11456 1829.54416  -2.550   0.0109 *
# ...

# %% [markdown]
# ### Disease

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy',
              !is.na(disease)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ disease + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# Metric_value ~ disease + westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 10681.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.9839 -0.6848 -0.0619  0.6698  4.3466
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  76.52    8.747
#  Residual                 114.76   10.713
# Number of obs: 1413, groups:  dataset_name, 15
#
# Fixed effects:
#                                          Estimate Std. Error        df t value
# (Intercept)                               42.9185     7.4534  235.5819   5.758
# diseasecoeliac;gestational_diabetes;CMV   -5.8492    11.9948   21.6186  -0.488
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_trt',
              !is.na(disease)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ disease + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# Metric_value ~ disease + westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 10109.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1740 -0.6555 -0.0077  0.6848  3.0556
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 59.31    7.701
#  Residual                 76.15    8.726
# Number of obs: 1413, groups:  dataset_name, 15
#
# Fixed effects:
#                                          Estimate Std. Error        df t value
# (Intercept)                               36.9162     6.1533  251.5102   5.999
# diseasecoeliac;gestational_diabetes;CMV   -6.0052    10.2351   23.7763  -0.587
# ...

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'shannon',
              !is.na(disease)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ disease + westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.00234975 (tol = 0.002, component 1)”
#
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# Metric_value ~ disease + westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 1938.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2548 -0.5584  0.0961  0.6557  2.5816
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1568   0.3960
#  Residual                 0.2207   0.4697
# Number of obs: 1413, groups:  dataset_name, 15
#
# Fixed effects:
#                                           Estimate Std. Error         df
# ...

# %% [markdown]
# ### BMI

# %%
alpha_div_f %>%
    dt_filter(!is.na(disease),
              !is.na(BMI)) %>% unique_n('Samples', Sample)
alpha_div_f %>%
    dt_filter(!is.na(disease),
              !is.na(BMI)) %>% unique_n('Studies', dataset_name)
# Out:
# No. of unique Samples: 918
# No. of unique Studies: 11

# %%
p = alpha_div_f %>%
    dt_filter(!is.na(disease),
              !is.na(BMI)) %>% 
    dt_mutate(BMI = car::bcPower(BMI, -1)) %>%
    ggplot(aes(BMI)) +
    geom_histogram(bins=30) +
    theme()

p.dims(3,2)
plot(p)
# Out:
# plot without title

# %%
fm = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy',
              !is.na(disease),
              !is.na(BMI)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ disease + westernized + age + gender + BMI + (1 | dataset_name), data=.) 

summary(fm)
anova(fm, type='II')
# Out:
# Correlation matrix not shown by default, as p = 14 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ disease + westernized + age + gender + BMI + (1 |
#     dataset_name)
#    Data: .
#
# REML criterion at convergence: 6793.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3639 -0.6577 -0.0564  0.6638  3.4653
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  98.37    9.918
#  Residual                 100.54   10.027
# Number of obs: 918, groups:  dataset_name, 11
#
# Fixed effects:
#                                          Estimate Std. Error        df t value
# (Intercept)                              179.7355    57.1777  903.9973   3.143
# diseasecoeliac;gestational_diabetes;CMV   -7.0152    12.8711   12.9968  -0.545
# ...

# %% [markdown]
# ### lmer: westernization summary

# %% [markdown]
# #### PD_phy

# %%
fm1 = alpha_div %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm1)
fm1_aov = anova(fm1, type='II')
fm1_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 25668.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.6556 -0.6645 -0.0168  0.6620  4.2644
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  41.89    6.472
#  Residual                 121.60   11.027
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                 Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)       58.272      1.685  78.204  34.584  < 2e-16 ***
# westernizedTRUE   -7.512      1.589 331.406  -4.728 3.35e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.718
#             Sum Sq   Mean Sq  NumDF DenDF    F value  Pr(>F)
# ...

# %%
fm2 = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm2)
fm2_aov = anova(fm2, type='II')
fm2_aov
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0022742 (tol = 0.002, component 1)”
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 14048.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.9397 -0.6655 -0.0208  0.6556  4.3082
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  55.26    7.434
#  Residual                 116.76   10.806
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                 Estimate Std. Error       df t value Pr(>|t|)
# (Intercept)       40.403      6.482  303.287   6.233 1.53e-09 ***
# westernizedTRUE  -16.923      3.229   38.309  -5.241 6.10e-06 ***
# age               11.014      2.379 1700.829   4.630 3.93e-06 ***
# ...

# %%
fm3 = alpha_div_f %>%
    dt_filter(Metric == 'pd_phy',
              !is.na(BMI)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name), data=.) 

summary(fm3)
fm3_aov = anova(fm3, type='II')
fm3_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 6983.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3278 -0.6782 -0.0608  0.6608  3.4249
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept)  74.21    8.615
#  Residual                 101.33   10.066
# Number of obs: 935, groups:  dataset_name, 11
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)      186.6312    55.8056  928.7850   3.344 0.000858 ***
# westernizedTRUE  -20.0717     4.0943   57.0663  -4.902 8.22e-06 ***
# age               12.4256     2.8057  925.8087   4.429 1.06e-05 ***
# gendermale        -2.7604     0.6764  922.2766  -4.081 4.87e-05 ***
# BMI             -153.7737    58.6038  928.1240  -2.624 0.008834 **
# ---
# ...

# %%
# formatting
x = fm1_aov %>% t %>% as.data.frame
x$coef = rownames(x)
x$lmer_model = 'alpha_div ~ westernized + (1 | dataset)'
y = fm2_aov %>% t %>% as.data.frame
y$coef = rownames(y)
y$lmer_model = 'alpha_div ~ westernized + age + gender + (1 | dataset)'
z = fm3_aov %>% t %>% as.data.frame
z$coef = rownames(z)
z$lmer_model = 'alpha_div ~ westernized + age + gender + BMI (1 | dataset)'

lmer_pd_phy = list(x %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   y %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   z %>% dt_pivot_longer(cols = c(-coef, -lmer_model))) %>%
    do.call(rbind, .) %>%
    dt_filter(coef %in% c('F value', 'Pr(>F)')) %>%
    dt_mutate(coef = ifelse(coef == 'F value', 'F', 'P')) %>%
    dt_pivot_wider(names_from = coef, values_from = value)

lmer_pd_phy
# Out:
#   lmer_model                                                 name
# 1 alpha_div ~ westernized + (1 | dataset)                    westernized
# 2 alpha_div ~ westernized + age + gender + (1 | dataset)     age
# ⋮ ⋮                                                          ⋮
# 7 alpha_div ~ westernized + age + gender + BMI (1 | dataset) gender
# 8 alpha_div ~ westernized + age + gender + BMI (1 | dataset) westernized
#   F        P
# 1 22.35862 3.351083e-06
# 2 21.43786 3.932176e-06
# ⋮ ⋮        ⋮
# 7 16.65585 4.869355e-05
# 8 24.03294 8.216999e-06

# %% [markdown]
# #### PD_trt

# %%
fm1 = alpha_div %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm1)
fm1_aov = anova(fm1, type='II')
fm1_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 24359
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8763 -0.6286  0.0315  0.6675  4.2248
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 41.16    6.416
#  Residual                 81.94    9.052
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                 Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)       49.012      1.552  75.660  31.584  < 2e-16 ***
# westernizedTRUE   -3.771      1.368 534.451  -2.757  0.00603 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.672
#             Sum Sq   Mean Sq  NumDF DenDF    F value Pr(>F)
# ...

# %%
fm2 = alpha_div_f %>%
    dt_filter(Metric == 'pd_trt') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm2)
fm2_aov = anova(fm2, type='II')
fm2_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 13246.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.2082 -0.6477  0.0422  0.6716  3.0688
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 50.01    7.072
#  Residual                 75.28    8.676
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)       35.6056     5.3700  325.3423   6.630 1.39e-10 ***
# westernizedTRUE   -9.7507     2.8161   65.4441  -3.462 0.000948 ***
# age                7.9558     1.9184 1794.1106   4.147 3.52e-05 ***
# gendermale        -1.5232     0.4661 1834.4684  -3.268 0.001103 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
# ...

# %%
fm3 = alpha_div_f %>%
    dt_filter(Metric == 'pd_trt',
              !is.na(BMI)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name), data=.) 

summary(fm3)
fm3_aov = anova(fm3, type='II')
fm3_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 6659.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.4188 -0.6550  0.0182  0.6684  2.8739
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 52.88    7.272
#  Residual                 71.50    8.456
# Number of obs: 935, groups:  dataset_name, 11
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)      154.7340    46.8820  929.0490   3.301 0.001002 **
# westernizedTRUE   -9.5872     3.4450   70.1432  -2.783 0.006917 **
# age                8.8688     2.3571  926.7715   3.763 0.000179 ***
# gendermale        -2.3536     0.5682  923.6942  -4.142 3.75e-05 ***
# BMI             -126.8364    49.2311  928.4338  -2.576 0.010139 *
# ---
# ...

# %%
# formatting
x = fm1_aov %>% t %>% as.data.frame
x$coef = rownames(x)
x$lmer_model = 'alpha_div ~ westernized + (1 | dataset)'
y = fm2_aov %>% t %>% as.data.frame
y$coef = rownames(y)
y$lmer_model = 'alpha_div ~ westernized + age + gender + (1 | dataset)'
z = fm3_aov %>% t %>% as.data.frame
z$coef = rownames(z)
z$lmer_model = 'alpha_div ~ westernized + age + gender + BMI (1 | dataset)'

lmer_pd_trt = list(x %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   y %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   z %>% dt_pivot_longer(cols = c(-coef, -lmer_model))) %>%
    do.call(rbind, .) %>%
    dt_filter(coef %in% c('F value', 'Pr(>F)')) %>%
    dt_mutate(coef = ifelse(coef == 'F value', 'F', 'P')) %>%
    dt_pivot_wider(names_from = coef, values_from = value)

lmer_pd_trt
# Out:
#   lmer_model                                                 name
# 1 alpha_div ~ westernized + (1 | dataset)                    westernized
# 2 alpha_div ~ westernized + age + gender + (1 | dataset)     age
# ⋮ ⋮                                                          ⋮
# 7 alpha_div ~ westernized + age + gender + BMI (1 | dataset) gender
# 8 alpha_div ~ westernized + age + gender + BMI (1 | dataset) westernized
#   F         P
# 1  7.60170  6.030732e-03
# 2 17.19903  3.523239e-05
# ⋮ ⋮         ⋮
# 7 17.159235 3.752551e-05
# 8  7.744672 6.916703e-03

# %% [markdown]
# #### Shannon

# %%
fm1 = alpha_div %>%
    dt_filter(Metric == 'shannon') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + (1 | dataset_name), data=.) 

summary(fm1)
fm1_aov = anova(fm1, type='II')
fm1_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 4828.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0963 -0.5280  0.1397  0.6716  2.8939
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1235   0.3514
#  Residual                 0.2390   0.4889
# Number of obs: 3348, groups:  dataset_name, 33
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)       3.96807    0.08455  75.26443  46.934   <2e-16 ***
# westernizedTRUE  -0.12259    0.07410 553.98939  -1.654   0.0986 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# wstrnzdTRUE -0.668
#             Sum Sq    Mean Sq   NumDF DenDF    F value Pr(>F)
# ...

# %%
fm2 = alpha_div_f %>%
    dt_filter(Metric == 'shannon') %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + (1 | dataset_name), data=.) 

summary(fm2)
fm2_aov = anova(fm2, type='II')
fm2_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 2464.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9020 -0.5553  0.1150  0.6668  2.6166
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1325   0.3640
#  Residual                 0.2142   0.4628
# Number of obs: 1843, groups:  dataset_name, 17
#
# Fixed effects:
#                   Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)        3.11809    0.28449  363.60829  10.960  < 2e-16 ***
# westernizedTRUE   -0.22529    0.14777   67.37902  -1.525   0.1320
# age                0.41668    0.10224 1788.95384   4.075 4.79e-05 ***
# gendermale        -0.05357    0.02486 1835.33426  -2.155   0.0313 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %%
fm3 = alpha_div_f %>%
    dt_filter(Metric == 'shannon',
              !is.na(BMI)) %>%
    dt_mutate(age = log2(age),
              BMI = car::bcPower(BMI, -1)) %>%
    lmer(Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name), data=.) 

summary(fm3)
fm3_aov = anova(fm3, type='II')
fm3_aov
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Metric_value ~ westernized + age + gender + BMI + (1 | dataset_name)
#    Data: .
#
# REML criterion at convergence: 1279.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.7624 -0.5216  0.1091  0.6412  2.7662
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  dataset_name (Intercept) 0.1543   0.3928
#  Residual                 0.2200   0.4691
# Number of obs: 935, groups:  dataset_name, 11
#
# Fixed effects:
#                  Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)       9.23879    2.59976 928.99841   3.554 0.000399 ***
# westernizedTRUE  -0.20282    0.18939  75.09769  -1.071 0.287656
# age               0.43936    0.13070 926.29842   3.362 0.000806 ***
# gendermale       -0.09839    0.03152 924.65817  -3.122 0.001853 **
# BMI              -6.46698    2.73052 928.84031  -2.368 0.018069 *
# ---
# ...

# %%
# formatting
x = fm1_aov %>% t %>% as.data.frame
x$coef = rownames(x)
x$lmer_model = 'alpha_div ~ westernized + (1 | dataset)'
y = fm2_aov %>% t %>% as.data.frame
y$coef = rownames(y)
y$lmer_model = 'alpha_div ~ westernized + age + gender + (1 | dataset)'
z = fm3_aov %>% t %>% as.data.frame
z$coef = rownames(z)
z$lmer_model = 'alpha_div ~ westernized + age + gender + BMI (1 | dataset)'

lmer_shan = list(x %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   y %>% dt_pivot_longer(cols = c(-coef, -lmer_model)),
                   z %>% dt_pivot_longer(cols = c(-coef, -lmer_model))) %>%
    do.call(rbind, .) %>%
    dt_filter(coef %in% c('F value', 'Pr(>F)')) %>%
    dt_mutate(coef = ifelse(coef == 'F value', 'F', 'P')) %>%
    dt_pivot_wider(names_from = coef, values_from = value)

lmer_shan
# Out:
#   lmer_model                                                 name
# 1 alpha_div ~ westernized + (1 | dataset)                    westernized
# 2 alpha_div ~ westernized + age + gender + (1 | dataset)     age
# ⋮ ⋮                                                          ⋮
# 7 alpha_div ~ westernized + age + gender + BMI (1 | dataset) gender
# 8 alpha_div ~ westernized + age + gender + BMI (1 | dataset) westernized
#   F        P
# 1  2.73688 9.862245e-02
# 2 16.60960 4.792801e-05
# ⋮ ⋮        ⋮
# 7 9.746111 0.001852867
# 8 1.146770 0.287655984

# %% [markdown]
# #### Combined

# %%
df.dims(30)
lmer_res = list(PD_phy = lmer_pd_phy %>% dt_mutate(Method = 'Faith\'s PD (phy)'),
                PD_trt = lmer_pd_trt %>% dt_mutate(Method = 'Faith\'s PD (trt)'),
                shan = lmer_shan %>% dt_mutate(Method = 'Shannon')) %>%
    do.call(rbind, .)
lmer_res   
df.dims()
# Out:
#    lmer_model                                                 name
# 1  alpha_div ~ westernized + (1 | dataset)                    westernized
# 2  alpha_div ~ westernized + age + gender + (1 | dataset)     age
# 3  alpha_div ~ westernized + age + gender + (1 | dataset)     gender
# 4  alpha_div ~ westernized + age + gender + (1 | dataset)     westernized
# 5  alpha_div ~ westernized + age + gender + BMI (1 | dataset) BMI
# 6  alpha_div ~ westernized + age + gender + BMI (1 | dataset) age
# 7  alpha_div ~ westernized + age + gender + BMI (1 | dataset) gender
# 8  alpha_div ~ westernized + age + gender + BMI (1 | dataset) westernized
# 9  alpha_div ~ westernized + (1 | dataset)                    westernized
# 10 alpha_div ~ westernized + age + gender + (1 | dataset)     age
# 11 alpha_div ~ westernized + age + gender + (1 | dataset)     gender
# 12 alpha_div ~ westernized + age + gender + (1 | dataset)     westernized
# ...

# %%
p = lmer_res %>%
    ggplot(aes(name, F, fill=lmer_model)) +
    geom_bar(stat='identity', position='dodge') +
    geom_text(aes(label=formatC(P, format='e', digits=1)), 
              vjust=-0.1, position=position_dodge(width=0.9),
              size=2.2) +
    scale_fill_discrete('Linear\nmixed\neffects\nmodel') +
    scale_y_continuous(limits=c(0, 30)) +
    labs(x='Coefficient', y='F value') +
    facet_grid(Method ~ .) +
    theme_bw() +
    theme(
        legend.position='bottom',
        legend.text = element_text(size=8),
        legend.title = element_text(size=9)
    ) +
    guides(fill=guide_legend(nrow=3,byrow=TRUE))

p.dims(5,5)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    dt_mutate(lmer_model = dt_case(lmer_model == 'alpha_div ~ westernized + (1 | dataset)',
                                  'alpha_div ~\nwesternized +\n(1 | dataset)',
                                  lmer_model == 'alpha_div ~ westernized + age + gender + (1 | dataset)',
                                  'alpha_div ~ westernized +\nage + gender + (1 | dataset)',
                                   lmer_model == 'alpha_div ~ westernized + age + gender + BMI (1 | dataset)',
                                  'alpha_div ~ westernized +\nage + gender + BMI + (1 | dataset)')) %>%
    ggplot(aes(name, F, fill=Method)) +
    geom_bar(stat='identity', position='dodge') +
    geom_text(aes(label=formatC(P, format='e', digits=0)), 
              vjust=-0.1, size=2.4,
              position=position_dodge(width=0.9)) +
    scale_fill_discrete('Alpha diversity\nmeasure') +
    scale_y_continuous(limits=c(0,30)) +
    labs(x='Coefficient', y='F value') +
    facet_grid(. ~ lmer_model, scales='free_x', space='free_x') +
    theme_bw() +
    theme(
        panel.spacing = unit(0.1, "lines")
    )

p.dims(9.5,3)
plot(p)
# Out:
# plot without title

# %%
# x = alpha_div %>% dt_filter(Metric == 'shannon') %>% dt_pull(Metric_value)
# g = alpha_div %>% dt_filter(Metric == 'shannon') %>% dt_pull(westernized)
# pairwise.wialcox.test(x, g, p.adjust.method = 'BH', paired = FALSE)

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] lmerTest_3.1-1    lme4_1.1-21       Matrix_1.2-18     LeyLabRMisc_0.1.3
#  [5] PhyloMeasures_2.1 vegan_2.5-6       lattice_0.20-38   permute_0.9-5
#  [9] phyloseq_1.30.0   ape_5.3           tidytable_0.3.2   data.table_1.12.8
# [13] ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# ...
