# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Bracken" data-toc-modified-id="Bracken-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Bracken</a></span><ul class="toc-item"><li><span><a href="#Unclassified" data-toc-modified-id="Unclassified-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Unclassified</a></span><ul class="toc-item"><li><span><a href="#Filtered" data-toc-modified-id="Filtered-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Filtered</a></span></li></ul></li><li><span><a href="#Classified-reads" data-toc-modified-id="Classified-reads-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Classified reads</a></span><ul class="toc-item"><li><span><a href="#Filtered" data-toc-modified-id="Filtered-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Filtered</a></span></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Summarize bracken output for all datasets

# %% [markdown]
# # Var

# %%
# working dir
work_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/'
metadata_filt_file = file.path(work_dir, 'CurMetDat_metadata_filt-n1846.tsv')

# metagenome profiling 
profile_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP/'

# associated files
base_in_dir = '/ebio/abt3_projects/small_projects/nyoungblut/public_data_retireval/'
metadata_file = file.path(base_in_dir, 'CurMetDat-metagenomes', 'files', 'metadata', 'Filtered_CurMetDat_f.tsv')
sample_file_dir = file.path(base_in_dir, 'CurMetDat-metagenomes', 'files', 'sample_files')

# params
threads = 16

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(dtplyr)
library(tidytable)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt

# %%
df.dims()
setDTthreads(threads)

# %% [markdown]
# # Bracken

# %%
# full metadata
meta = Fread(metadata_file)
meta %>% unique_n('Samples', Sample)
meta
# Out:
# No. of unique Samples: 3594
#      dataset_name  Sample              subjectID body_site
# 1    AsnicarF_2017 MV_FEM1_t1Q14       MV_FEM1   stool
# 2    AsnicarF_2017 MV_FEM2_t1Q14       MV_FEM2   stool
# ⋮    ⋮             ⋮                   ⋮         ⋮
# 3593 ZellerG_2014  CCIS82944710ST-20-0 FR-730    stool
# 3594 ZellerG_2014  CCIS93040568ST-20-0 FR-682    stool
#      antibiotics_current_use study_condition disease age age_category gender ⋯
# 1    NA                      control         healthy NA  adult        female ⋯
# 2    NA                      control         healthy NA  adult        female ⋯
# ⋮    ⋮                       ⋮               ⋮       ⋮   ⋮            ⋮      ⋱
# 3593 NA                      control         healthy 38  adult        female ⋯
# 3594 NA                      control         healthy 65  adult        male   ⋯
#      il_1 glp_1 travel_destination urea_nitrogen disease_stage
# 1    NA   NA    NA                 NA            NA
# 2    NA   NA    NA                 NA            NA
# ⋮    ⋮    ⋮     ⋮                  ⋮             ⋮
# 3593 NA   NA    NA                 NA            NA
# 3594 NA   NA    NA                 NA            NA
#      uncurated_metadata family_member subject_n samp_n westernized
# 1    NA                 NA            1         1      TRUE
# 2    NA                 NA            1         1      TRUE
# ⋮    ⋮                  ⋮             ⋮         ⋮      ⋮
# 3593 NA                 NA            1         1      TRUE
# 3594 NA                 NA            1         1      TRUE

# %%
# filtered metadata
meta_f = Fread(metadata_filt_file)
meta_f %>% unique_n('Samples', Sample)
meta_f
# Out:
# No. of unique Samples: 1846
#      dataset               Sample      Run Lane Remote     subjectID
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  1   1    ERR636349  TRAVELRES1_2
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 1   1    ERR636358  TRAVELRES9_10
# ⋮    ⋮                     ⋮           ⋮   ⋮    ⋮          ⋮
# 5149 YeZ_2018              YEZ_N-38    1   1    SRR8675918 YEZ_N-38
# 5150 YeZ_2018              YEZ_N-37    1   1    SRR8675921 YEZ_N-37
#      body_site antibiotics_current_use study_condition disease ⋯ il_1 glp_1
# 1    stool     no                      control         healthy ⋯ NA   NA
# 2    stool     no                      control         healthy ⋯ NA   NA
# ⋮    ⋮         ⋮                       ⋮               ⋮       ⋱ ⋮    ⋮
# 5149 stool     no                      control         healthy ⋯ NA   NA
# 5150 stool     no                      control         healthy ⋯ NA   NA
#      travel_destination urea_nitrogen disease_stage uncurated_metadata
# 1    NA                 NA            NA            NA
# 2    LKA                NA            NA            NA
# ⋮    ⋮                  ⋮             ⋮             ⋮
# 5149 NA                 NA            NA            NA
# 5150 NA                 NA            NA            NA
#      family_member subject_n samp_n westernized
# 1    NA            1         1      TRUE
# 2    NA            1         1      TRUE
# ⋮    ⋮             ⋮         ⋮      ⋮
# 5149 NA            1         1      TRUE
# 5150 NA            1         1      TRUE

# %%
# checking key overlap
overlap(meta, meta_f, Sample, Sample)
# Out:
# intersect(x,y): 1846
# setdiff(x,y): 1748
# setdiff(y,x): 0
# union(x,y): 3594

# %% [markdown]
# ## Unclassified

# %%
# listing files
brk_uncls_files = list_files(profile_dir, 'all-combined_kraken-unclassified.tsv')
brk_uncls_files = brk_uncls_files[!grepl('(34_HuBif|36_EcoEvo)', brk_uncls_files)]
brk_uncls_files %>% length
brk_uncls_files %>% head(n=3)
# Out:
# [1] 33
# [1] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//01_CosteaPI_2017/kraken/all-combined_kraken-unclassified.tsv"
# [2] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//02_Obregon-TitoAJ_2015/kraken/all-combined_kraken-unclassified.tsv"
# [3] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//03_PasolliE_2018/kraken/all-combined_kraken-unclassified.tsv"

# %%
# reading in tables
brk_uncls = brk_uncls_files %>%
    files_to_list(-2) %>%
    plyr::llply(Fread) %>%
    data.table::rbindlist(use.names=TRUE, idcol='Dataset') %>%
    dt_mutate(Dataset = gsub('^[0-9]+_', '', Dataset))

brk_uncls  %>% unique_n('Samples', sample)
brk_uncls
# Out:
# No. of unique Samples: 3360
#      Dataset       sample            percent_reads num_reads_mapped_to_clade
# 1    CosteaPI_2017 halbarad-11-0-0   18.60         185981
# 2    CosteaPI_2017 scavenger-11-60-0 10.99         109942
# ⋮    ⋮             ⋮                 ⋮             ⋮
# 3359 YuJ_2015      SZAXPI017591-140  28.00         279999
# 3360 YuJ_2015      SZAXPI017592-142  21.41         214099
#      num_reads_mapped_to_taxon rank_code taxID scientific_name
# 1    185981                    U         0     unclassified
# 2    109942                    U         0     unclassified
# ⋮    ⋮                         ⋮         ⋮     ⋮
# 3359 279999                    U         0     unclassified
# 3360 214099                    U         0     unclassified

# %%
# checking key overlap
overlap(brk_uncls, meta, sample, Sample)
cat('---\n')
overlap(brk_uncls, meta, Dataset, dataset_name)
# Out:
# intersect(x,y): 3360
# setdiff(x,y): 0
# setdiff(y,x): 234
# union(x,y): 3594
# ---
# intersect(x,y): 33
# setdiff(x,y): 0
# setdiff(y,x): 4
# union(x,y): 37

# %%
# joining with metadata
brk_uncls = brk_uncls %>%
    dt_inner_join(meta %>% dt_rename('sample' = Sample, 'Dataset' = dataset_name), 
                  by=c('sample', 'Dataset')) 

brk_uncls
# Out:
# Warning message in if (by_x %notin% colnames(x)) stop("by.x columns not in x"):
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (by_y %notin% colnames(y)) stop("by.y columns not in y"):
# “the condition has length > 1 and only the first element will be used”
#      Dataset       sample            percent_reads num_reads_mapped_to_clade
# 1    AsnicarF_2017 MV_FEM1_t1Q14     16.14         161357
# 2    AsnicarF_2017 MV_FEM2_t1Q14     24.81         248051
# ⋮    ⋮             ⋮                 ⋮             ⋮
# 3359 ZeeviD_2015   PNP_Validation_45 19.22         192152
# 3360 ZeeviD_2015   PNP_Validation_46 17.94         179448
#      num_reads_mapped_to_taxon rank_code taxID scientific_name
# 1    161357                    U         0     unclassified
# 2    248051                    U         0     unclassified
# ⋮    ⋮                         ⋮         ⋮     ⋮
# 3359 192152                    U         0     unclassified
# 3360 179448                    U         0     unclassified
#      subjectID         body_site ⋯ il_1 glp_1 travel_destination urea_nitrogen
# 1    MV_FEM1           stool     ⋯ NA   NA    NA                 NA
# 2    MV_FEM2           stool     ⋯ NA   NA    NA                 NA
# ⋮    ⋮                 ⋮         ⋱ ⋮    ⋮     ⋮                  ⋮
# 3359 PNP_Validation_45 stool     ⋯ NA   NA    NA                 NA
# 3360 PNP_Validation_46 stool     ⋯ NA   NA    NA                 NA
#      disease_stage uncurated_metadata family_member subject_n samp_n
# 1    NA            NA                 NA            1         1
# 2    NA            NA                 NA            1         1
# ⋮    ⋮             ⋮                  ⋮             ⋮         ⋮
# 3359 NA            NA                 NA            1         1
# 3360 NA            NA                 NA            1         1
#      westernized
# 1    TRUE
# 2    TRUE
# ⋮    ⋮
# 3359 TRUE
# 3360 TRUE

# %%
# summarizing
brk_uncls_s = brk_uncls %>%
    dt_mutate(perc_reads_cls = 100 - percent_reads) %>%
    dt_mutate(median_perc_reads_cls = median(perc_reads_cls), 
              by=list(Dataset)) %>%
    dt_mutate(Dataset = Dataset %>% reorder(-median_perc_reads_cls)) 

brk_uncls_s
# Out:
#      Dataset       sample            percent_reads num_reads_mapped_to_clade
# 1    AsnicarF_2017 MV_FEM1_t1Q14     16.14         161357
# 2    AsnicarF_2017 MV_FEM2_t1Q14     24.81         248051
# ⋮    ⋮             ⋮                 ⋮             ⋮
# 3359 ZeeviD_2015   PNP_Validation_45 19.22         192152
# 3360 ZeeviD_2015   PNP_Validation_46 17.94         179448
#      num_reads_mapped_to_taxon rank_code taxID scientific_name
# 1    161357                    U         0     unclassified
# 2    248051                    U         0     unclassified
# ⋮    ⋮                         ⋮         ⋮     ⋮
# 3359 192152                    U         0     unclassified
# 3360 179448                    U         0     unclassified
#      subjectID         body_site ⋯ travel_destination urea_nitrogen
# 1    MV_FEM1           stool     ⋯ NA                 NA
# 2    MV_FEM2           stool     ⋯ NA                 NA
# ⋮    ⋮                 ⋮         ⋱ ⋮                  ⋮
# 3359 PNP_Validation_45 stool     ⋯ NA                 NA
# 3360 PNP_Validation_46 stool     ⋯ NA                 NA
#      disease_stage uncurated_metadata family_member subject_n samp_n
# 1    NA            NA                 NA            1         1
# 2    NA            NA                 NA            1         1
# ⋮    ⋮             ⋮                  ⋮             ⋮         ⋮
# 3359 NA            NA                 NA            1         1
# 3360 NA            NA                 NA            1         1
#      westernized perc_reads_cls median_perc_reads_cls
# 1    TRUE        83.86          80.875
# 2    TRUE        75.19          80.875
# ⋮    ⋮           ⋮              ⋮
# 3359 TRUE        80.78          78.6
# 3360 TRUE        82.06          78.6

# %%
p = brk_uncls_s %>%
    ggplot(aes(Dataset, perc_reads_cls, color=westernized)) +
    geom_boxplot() +
    labs(y='% reads classified') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )
    
p.dims(8,3)
plot(p)
# Out:
# plot without title

# %%
p = brk_uncls_s %>%
    ggplot(aes(westernized, perc_reads_cls)) +
    geom_boxplot() +
    labs(y='% reads classified') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )
    
p.dims(4,3)
plot(p)
# Out:
# plot without title

# %%
p = brk_uncls_s %>%
    ggplot(aes(Dataset, perc_reads_cls, color=gender)) +
    geom_boxplot() +
    labs(y='% reads classified') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )
    
p.dims(9,3)
plot(p)
# Out:
# plot without title

# %%
p = brk_uncls_s %>%
    ggplot(aes(age, perc_reads_cls, color=Dataset)) +
    geom_point(shape='O', alpha=0.8) +
    labs(y='% reads classified') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )
    
p.dims(9,5)
plot(p)
# Out:
# Warning message:
# “Removed 1431 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ### Filtered
#
# * Just samples with "good" metadata

# %%
# checking key ovlerap
overlap(brk_uncls, meta_f, sample, Sample)
# Out:
# intersect(x,y): 1843
# setdiff(x,y): 1517
# setdiff(y,x): 3
# union(x,y): 3363

# %%
brk_uncls_f = brk_uncls %>%
    dt_inner_join(meta_f %>% dt_rename('sample'=Sample, 'Dataset'=dataset),
                  by=c('sample', 'Dataset'))
brk_uncls_f
# Out:
# Warning message in if (by_x %notin% colnames(x)) stop("by.x columns not in x"):
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (by_y %notin% colnames(y)) stop("by.y columns not in y"):
# “the condition has length > 1 and only the first element will be used”
#      Dataset               sample      percent_reads num_reads_mapped_to_clade
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  31.23         312348
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 35.71         357144
# ⋮    ⋮                     ⋮           ⋮             ⋮
# 5146 YeZ_2018              YEZ_N-38    11.51         115065
# 5147 YeZ_2018              YEZ_N-37    19.44         194379
#      num_reads_mapped_to_taxon rank_code taxID scientific_name subjectID
# 1    312348                    U         0     unclassified    TRAVELRES1_2
# 2    357144                    U         0     unclassified    TRAVELRES9_10
# ⋮    ⋮                         ⋮         ⋮     ⋮               ⋮
# 5146 115065                    U         0     unclassified    YEZ_N-38
# 5147 194379                    U         0     unclassified    YEZ_N-37
#      body_site ⋯ i.il_1 i.glp_1 i.travel_destination i.urea_nitrogen
# 1    stool     ⋯ NA     NA      NA                   NA
# 2    stool     ⋯ NA     NA      LKA                  NA
# ⋮    ⋮         ⋱ ⋮      ⋮       ⋮                    ⋮
# 5146 stool     ⋯ NA     NA      NA                   NA
# 5147 stool     ⋯ NA     NA      NA                   NA
#      i.disease_stage i.uncurated_metadata i.family_member i.subject_n i.samp_n
# 1    NA              NA                   NA              1           1
# 2    NA              NA                   NA              1           1
# ⋮    ⋮               ⋮                    ⋮               ⋮           ⋮
# 5146 NA              NA                   NA              1           1
# 5147 NA              NA                   NA              1           1
#      i.westernized
# 1    TRUE
# 2    TRUE
# ⋮    ⋮
# 5146 TRUE
# 5147 TRUE

# %%
# summarizing
brk_uncls_f_s = brk_uncls_f %>%
    dt_mutate(perc_reads_cls = 100 - percent_reads) %>%
    dt_mutate(median_perc_reads_cls = median(perc_reads_cls), by=list(Dataset)) %>%
    dt_mutate(Dataset = Dataset %>% reorder(-median_perc_reads_cls)) 

brk_uncls_f_s
# Out:
#      Dataset               sample      percent_reads num_reads_mapped_to_clade
# 1    Bengtsson-PalmeJ_2015 TRAVELRES1  31.23         312348
# 2    Bengtsson-PalmeJ_2015 TRAVELRES10 35.71         357144
# ⋮    ⋮                     ⋮           ⋮             ⋮
# 5146 YeZ_2018              YEZ_N-38    11.51         115065
# 5147 YeZ_2018              YEZ_N-37    19.44         194379
#      num_reads_mapped_to_taxon rank_code taxID scientific_name subjectID
# 1    312348                    U         0     unclassified    TRAVELRES1_2
# 2    357144                    U         0     unclassified    TRAVELRES9_10
# ⋮    ⋮                         ⋮         ⋮     ⋮               ⋮
# 5146 115065                    U         0     unclassified    YEZ_N-38
# 5147 194379                    U         0     unclassified    YEZ_N-37
#      body_site ⋯ i.travel_destination i.urea_nitrogen i.disease_stage
# 1    stool     ⋯ NA                   NA              NA
# 2    stool     ⋯ LKA                  NA              NA
# ⋮    ⋮         ⋱ ⋮                    ⋮               ⋮
# 5146 stool     ⋯ NA                   NA              NA
# 5147 stool     ⋯ NA                   NA              NA
#      i.uncurated_metadata i.family_member i.subject_n i.samp_n i.westernized
# 1    NA                   NA              1           1        TRUE
# 2    NA                   NA              1           1        TRUE
# ⋮    ⋮                    ⋮               ⋮           ⋮        ⋮
# 5146 NA                   NA              1           1        TRUE
# 5147 NA                   NA              1           1        TRUE
#      perc_reads_cls median_perc_reads_cls
# 1    68.77          80.84
# 2    64.29          80.84
# ⋮    ⋮              ⋮
# 5146 88.49          88.85
# 5147 80.56          88.85

# %%
p = brk_uncls_f_s %>%
    ggplot(aes(Dataset, perc_reads_cls, color=westernized)) +
    geom_boxplot() +
    labs(y='% reads classified') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )
    
p.dims(6,3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Classified reads
#
# * microbial reads

# %%
# listing files
brk_cls_files = list_files(profile_dir, 'all-combined-bracken.tsv') 
brk_cls_files = brk_cls_files[!grepl('(34_HuBif|36_EcoEvo)', brk_cls_files)]
brk_cls_files %>% length
brk_cls_files %>% head(n=3)
# Out:
# [1] 33
# [1] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//01_CosteaPI_2017/kraken/all-combined-bracken.tsv"
# [2] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//02_Obregon-TitoAJ_2015/kraken/all-combined-bracken.tsv"
# [3] "/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP//03_PasolliE_2018/kraken/all-combined-bracken.tsv"

# %%
# reading tables
brk_cls = brk_cls_files %>% files_to_list(-2) %>%
    plyr::llply(read_bracken) %>%
    data.table::rbindlist(use.names=TRUE, idcol='dataset')

brk_cls
# Out:
#         dataset          name                         taxonomy_id taxonomy_lvl
# 1       01_CosteaPI_2017 s__Caecibacter massiliensis  108259      S
# 2       01_CosteaPI_2017 s__UBA1777 sp002350825       178550      S
# ⋮       ⋮                ⋮                            ⋮           ⋮
# 5133955 33_YuJ_2015      s__Serratia grimesii         121568      S
# 5133956 33_YuJ_2015      s__Bacteroides_A sp002161565 119189      S
#         Domain   Phylum         Class               Order
# 1       Bacteria Firmicutes_C   Negativicutes       Veillonellales
# 2       Bacteria Firmicutes_A   Clostridia          Oscillospirales
# ⋮       ⋮        ⋮              ⋮                   ⋮
# 5133955 Bacteria Proteobacteria Gammaproteobacteria Enterobacterales
# 5133956 Bacteria Bacteroidota   Bacteroidia         Bacteroidales
#         Family             Genus         Species
# 1       Megasphaeraceae    Caecibacter   Caecibacter massiliensis
# 2       Oscillospiraceae   UBA1777       UBA1777 sp002350825
# ⋮       ⋮                  ⋮             ⋮
# 5133955 Enterobacteriaceae Serratia      Serratia grimesii
# 5133956 Bacteroidaceae     Bacteroides_A Bacteroides_A sp002161565
#         Sample           Abundance
# 1       halbarad.11.0.0  0
# 2       halbarad.11.0.0  0
# ⋮       ⋮                ⋮
# 5133955 SZAXPI017592.142 0
# 5133956 SZAXPI017592.142 0

# %%
# number of samples
brk_cls %>% unique_n('Samples', Sample)
# Out:
# No. of unique Samples: 3360

# %%
# key overlap
overlap(brk_cls, meta, Sample, Sample)
# Out:
# intersect(x,y): 2923
# setdiff(x,y): 437
# setdiff(y,x): 671
# union(x,y): 4031

# %%
# key overlap with metadata samples renamed
overlap(brk_cls, meta %>% dt_pull(Sample) %>% gsub('-', '.', .), Sample)
# Out:
# intersect(x,y): 3360
# setdiff(x,y): 0
# setdiff(y,x): 234
# union(x,y): 3594

# %%
# phylum prevalence
brk_cls_s = brk_cls %>%
    dt_summarize(prev = sum(Abundance > 1e-5) / length(Abundance) * 100,
                 by=list(Domain, Phylum))

brk_cls_s %>% dt_pull(prev) %>% summary_x

p = brk_cls_s %>%
    dt_mutate(Phylum = Phylum %>% reorder(prev)) %>%
    ggplot(aes(Phylum, prev, fill=Domain)) +
    geom_bar(stat='identity') +
    coord_flip() +
    labs(y='Prevalence (%)') +
    theme_bw() 

p.dims(4,6.8)
plot(p)
# Out:
#   Min.      1st Qu.   Median Mean    3rd Qu.  Max.     sd     sd_err_of_mean
# . 0.3039514 0.9259259 1.25   3.35332 3.030303 26.45213 10.147 4.142
# plot without title

# %%
# phylum abundance
brk_cls_s = brk_cls %>%
    dt_mutate(Abundance = Abundance * 100) %>%
    dt_summarize(mean_abund = mean(Abundance),
              sd_abund = sd(Abundance),
              by=list(Domain, Phylum))
brk_cls_s %>% dt_pull(mean_abund) %>% summary_x

p = brk_cls_s %>%
    dt_mutate(Phylum = Phylum %>% reorder(mean_abund)) %>%
    ggplot(aes(Phylum, mean_abund, fill=Domain)) +
    geom_linerange(aes(ymin=ifelse(mean_abund - sd_abund < 0, 0, mean_abund - sd_abund),
                       ymax=mean_abund + sd_abund)) +
    geom_point() +
    coord_flip() +
    labs(y='Abundance (%)') +
    theme_bw() 

p.dims(6,6.8)
plot(p)
# Out:
#   Min.         1st Qu.  Median       Mean        3rd Qu.     Max.     sd
# . 6.990881e-05 0.000302 0.0005731914 0.009253291 0.005196491 0.117745 0.047
#   sd_err_of_mean
# . 0.019
# plot without title

# %% [markdown]
# ### Filtered

# %%
brk_cls_j = brk_cls %>%
    dt_select(-taxonomy_id, -taxonomy_lvl) %>% 
    dt_inner_join(meta_f %>% dt_rename('Dataset' = dataset) %>%
                    dt_select(Sample, Dataset, body_site,
                              study_condition, age, gender,
                              country, westernized, 
                              sequencing_platform, number_reads)) 

brk_cls_j %>% unique_n('Samples', Sample)
brk_cls_j
# Out:
# No. of unique Samples: 1741
#         dataset                  name                           Domain
# 1       19_Bengtsson-PalmeJ_2015 s__An200 sp003268275           Bacteria
# 2       19_Bengtsson-PalmeJ_2015 s__Prevotella sp900107705      Bacteria
# ⋮       ⋮                        ⋮                              ⋮
# 6831178 21_XieH_2016             s__Nitrosoglobus terrae        Bacteria
# 6831179 21_XieH_2016             s__Phoenicibacter massiliensis Bacteria
#         Phylum           Class               Order
# 1       Firmicutes_A     Clostridia          Oscillospirales
# 2       Bacteroidota     Bacteroidia         Bacteroidales
# ⋮       ⋮                ⋮                   ⋮
# 6831178 Proteobacteria   Gammaproteobacteria Nitrosococcales
# 6831179 Actinobacteriota Coriobacteriia      Coriobacteriales
#         Family             Genus          Species
# 1       Acutalibacteraceae An200          An200 sp003268275
# 2       Bacteroidaceae     Prevotella     Prevotella sp900107705
# ⋮       ⋮                  ⋮              ⋮
# 6831178 Nitrosococcaceae   Nitrosoglobus  Nitrosoglobus terrae
# 6831179 Eggerthellaceae    Phoenicibacter Phoenicibacter massiliensis
#         Sample          Abundance Dataset               body_site
# 1       TRAVELRES1      0         Bengtsson-PalmeJ_2015 stool
# 2       TRAVELRES1      0         Bengtsson-PalmeJ_2015 stool
# ⋮       ⋮               ⋮         ⋮                     ⋮
# 6831178 YSZC12003_37880 0         XieH_2016             stool
# 6831179 YSZC12003_37880 0         XieH_2016             stool
#         study_condition age gender country westernized sequencing_platform
# 1       control         25  female SWE     TRUE        IlluminaHiSeq
# 2       control         25  female SWE     TRUE        IlluminaHiSeq
# ⋮       ⋮               ⋮   ⋮      ⋮       ⋮           ⋮
# 6831178 control         42  female GBR     TRUE        IlluminaHiSeq
# 6831179 control         42  female GBR     TRUE        IlluminaHiSeq
#         number_reads
# 1       147984098
# 2       147984098
# ⋮       ⋮
# 6831178 63467504
# 6831179 63467504

# %%
# phylum prevalence
brk_cls_j_s = brk_cls_j %>%
    dt_summarize(prev = sum(Abundance > 1e-5) / length(Abundance) * 100,
                 by=list(Domain, Phylum, westernized))

brk_cls_j_s %>% dt_pull(prev) %>% summary_x

p = brk_cls_j_s %>%
    dt_mutate(westernized = ifelse(westernized, 'westernized', 'non-westernized'),
              Phylum = Phylum %>% reorder(prev)) %>%
    ggplot(aes(Phylum, prev, fill=Domain)) +
    geom_bar(stat='identity') +
    facet_wrap(~ westernized) +
    coord_flip() +
    labs(y='Prevalence (%)') +
    theme_bw() 

p.dims(5,6.5)
plot(p)
# Out:
#   Min. 1st Qu.   Median   Mean     3rd Qu.  Max.     sd     sd_err_of_mean
# . 0    0.9643809 1.236013 4.568076 4.988372 29.91293 11.433 4.668
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/tidyverse/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.3 tidytable_0.3.2   dtplyr_1.0.0      data.table_1.12.8
# [5] ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.3       plyr_1.8.5       pillar_1.4.3     compiler_3.6.2
#  [5] base64enc_0.1-3  tools_3.6.2      bit_1.1-15.2     zeallot_0.1.0
#  [9] digest_0.6.23    uuid_0.1-2       jsonlite_1.6     evaluate_0.14
# [13] tibble_2.1.3     lifecycle_0.1.0  gtable_0.3.0     pkgconfig_2.0.3
# [17] rlang_0.4.2      IRdisplay_0.7.0  IRkernel_1.1     repr_1.0.2
# [21] withr_2.1.2      vctrs_0.2.1      bit64_0.9-7      grid_3.6.2
# [25] tidyselect_0.2.5 glue_1.3.1       R6_2.4.1         pbdZMQ_0.3-3
# [29] farver_2.0.2     purrr_0.3.3      magrittr_1.5     backports_1.1.5
# [33] scales_1.1.0     htmltools_0.4.0  assertthat_0.2.1 colorspace_1.4-1
# [37] labeling_0.3     lazyeval_0.2.2   munsell_0.5.0    crayon_1.3.4
