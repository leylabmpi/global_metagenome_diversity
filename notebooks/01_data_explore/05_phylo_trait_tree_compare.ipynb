# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Relabeling-genome-phylogeny" data-toc-modified-id="Relabeling-genome-phylogeny-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Relabeling genome phylogeny</a></span></li><li><span><a href="#Checks" data-toc-modified-id="Checks-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Global-congruence" data-toc-modified-id="Global-congruence-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Global congruence</a></span><ul class="toc-item"><li><span><a href="#PH85" data-toc-modified-id="PH85-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>PH85</a></span></li><li><span><a href="#Mantel" data-toc-modified-id="Mantel-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Mantel</a></span></li><li><span><a href="#cospeciation" data-toc-modified-id="cospeciation-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>cospeciation</a></span></li><li><span><a href="#Procrustes" data-toc-modified-id="Procrustes-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Procrustes</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Compare the genome-based GTDB phylogeny versus the traitar trait dendrogam
# * Methods for comparing:
#   * global
#     * PH85 & `Kuhner and Felsenstein`

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/phy-trt_comp/'

# genome phylogeny
gen_phy_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/phylogeny/ar122-bac120_r89_1per-GTDB-Spec_gte50comp-lt5cont.nwk'

# traitar phenotypes
## majority votes
trt_jac_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/predictions_flat_majority-votes_combined_jaccard.nwk'
## single votes
trt_bray_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/predictions_flat_single-votes_combined_bray.nwk'

# GTDBr89 genome metadata
meta_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/metadata_1per-GTDB-Spec_gte50comp-lt5cont_wtaxID_wPath.tsv'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(tidytable)
library(ape)
library(vegan)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt
#
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.5-6

# %%
df.dims()
setDTthreads(threads)
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/phy-trt_comp/

# %%
library(openblasctl)
openblas_set_num_threads(4)

# %%
# running on the cluster
library(future)
library(future.batchtools)
library(purrr)
library(furrr)
options(future.wait.interval = 2.0)
# Out:
# Attaching package: ‘purrr’
#
#
# The following object is masked from ‘package:data.table’:
#
#     transpose

# %% [markdown]
# # Load

# %%
tax_levs = c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species')
meta = Fread(meta_file) %>%
    dt_select(ncbi_genbank_assembly_accession, accession, ncbi_organism_name, gtdb_taxonomy) %>%
    dt_rename('GTDB_accession' = accession) %>%
    dt_separate(gtdb_taxonomy, tax_levs, sep=';') 

meta %>% unique_n('NCBI accessions', ncbi_genbank_assembly_accession)
meta
# Out:
# No. of unique NCBI accessions: 23360
#       ncbi_genbank_assembly_accession GTDB_accession
# 1     GCA_002789635.1                 GB_GCA_002789635.1
# 2     GCA_001784635.1                 GB_GCA_001784635.1
# ⋮     ⋮                               ⋮
# 23359 GCA_001775395.1                 GB_GCA_001775395.1
# 23360 GCA_002791595.1                 GB_GCA_002791595.1
#       ncbi_organism_name
# 1     GB_GCA_002789635.1_Candidatus Aenigmarchaeota archaeon CG_4_9_14_3_um_filter_37_18
# 2     GB_GCA_001784635.1_Candidatus Micrarchaeota archaeon RBG_16_49_10
# ⋮     ⋮
# 23359 GB_GCA_001775395.1_candidate division Zixibacteria bacterium RBG_16_53_22
# 23360 GB_GCA_002791595.1_candidate division Zixibacteria bacterium CG_4_9_14_3_um_filter_46_8
#       Domain      Phylum             Class             Order
# 1     d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia o__CG10238-14
# 2     d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia o__CG10238-14
# ⋮     ⋮           ⋮                  ⋮                 ⋮
# 23359 d__Bacteria p__Zixibacteria    c__MSB-5A5        o__UBA10806
# 23360 d__Bacteria p__Zixibacteria    c__MSB-5A5        o__UM-FILTER-46-8
#       Family            Genus             Species
# 1     f__CG10238-14     g__CG10238-14     s__CG10238-14 sp002789635
# 2     f__CG10238-14     g__RBG-16-49-10   s__RBG-16-49-10 sp001784635
# ⋮     ⋮                 ⋮                 ⋮
# 23359 f__UBA10806       g__UBA10806       s__UBA10806 sp001775395
# 23360 f__UM-FILTER-46-8 g__UM-FILTER-46-8 s__UM-FILTER-46-8 sp002791595

# %%
gen_phy = read.tree(gen_phy_file)
gen_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	RS_GCF_000296615.1, RS_GCF_000337335.1, RS_GCF_002355655.1, RS_GCF_001280455.1, RS_GCF_000337035.1, RS_GCF_002114285.1, ...
# Node labels:
# 	100.0, d__Archaea100.0, 97.0, 99.0, 100.0, 100.0:p__Halobacterota, ...
#
# Rooted; includes branch lengths.

# %%
trt_jac = read.tree(trt_jac_file)
trt_jac
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	GCA_900048045.1, GCA_003284185.1, GCA_003282425.1, GCA_003265155.1, GCA_003260325.1, GCA_003251635.1, ...
#
# Rooted; includes branch lengths.

# %%
trt_bray = read.tree(trt_bray_file)
trt_bray
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	GCA_900048045.1, GCA_003284185.1, GCA_003214255.1, GCA_003021915.1, GCA_002782345.1, GCA_002687905.1, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# ## Relabeling genome phylogeny
#
# * replacing `GTDB_accession` with `NCBI_accession`

# %%
# checking overlap
overlap(gen_phy$tip.label, meta$GTDB_accession)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %%
tmp = meta %>%
    as.data.frame
rownames(tmp) = tmp$GTDB_accession

gen_phy$tip.label = tmp[gen_phy$tip.label,]$ncbi_genbank_assembly_accession

rm(tmp); gc()
gen_phy
# Out:
#        used    (Mb)  gc trigger (Mb)  max used (Mb)
# Ncells 2019435 107.9  4669308   249.4  2734811 146.1
# Vcells 5257708  40.2 12038373    91.9 11779802  89.9
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	GCA_000296615.1, GCA_000337335.1, GCA_002355655.1, GCA_001280455.1, GCA_000337035.1, GCA_002114285.1, ...
# Node labels:
# 	100.0, d__Archaea100.0, 97.0, 99.0, 100.0, 100.0:p__Halobacterota, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# ## Checks

# %%
overlap(gen_phy$tip.label, trt_jac$tip.label)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %%
overlap(gen_phy$tip.label, trt_bray$tip.label)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %% [markdown]
# # Global congruence

# %% [markdown]
# ## PH85

# %%
# genome-phy versus genome-phy (neg. control)
genPhy_genPhy_PH85 = dist.topo(unroot(gen_phy), unroot(gen_phy), method = "PH85")
genPhy_genPhy_PH85
# Out:
#       tree1
# tree2     0

# %%
# genome-phy versus trait-majority
genPhy_trtJac_PH85 = dist.topo(unroot(gen_phy), unroot(trt_jac), method = "PH85")
genPhy_trtJac_PH85
# Out:
#       tree1
# tree2 44380

# %%
# genome-phy versus trait-single
genPhy_trtBray_PH85 = dist.topo(unroot(gen_phy), unroot(trt_bray), method = "PH85")
genPhy_trtBray_PH85

# %%
# trait-majority versus trait-single
trtJac_trtBray_PH85 = dist.topo(unroot(trt_jac), unroot(trt_bray), method = "PH85")
trtJac_trtBray_PH85

# %% [markdown]
# ## Mantel

# %%
coph <- function(x, path = FALSE) {
  if (is.null(attr(x, "order")) || attr(x, "order") == "cladewise")
    x <- reorder(x, "postorder")
  el <- x$edge.length
  if (path) el <- rep(1.0, nrow(x$edge))
  nTips <- as.integer(length(x$tip.label))
  nNode <- as.integer(x$Nnode)
  dm <- cophenetic_cpp(x$edge, as.double(el), nTips, nNode)
  attr(dm, "Size") <- nTips
  attr(dm, "Labels") <- x$tip.label
  attr(dm, "Diag") <- FALSE
  attr(dm, "Upper") <- FALSE
  class(dm) <- "dist"
  dm
}

# %%
# converting phylogeny to ultrametric dendrogram to distance matrix
force_ultra = function(x){
    phytools::force.ultrametric(x,  method=c("extend"))
}

phy2cophenetic = function(phy){
  x = phy %>%
    unroot %>%
    multi2di %>%
    compute.brlen(1) %>%
    force_ultra %>%
    cophenetic 
}

# test
#phy2cophenetic(rtree(10)) %>% dim

# %%
# phylogeny to matrix
gen_phy_mtx = phy2cophenetic(gen_phy)
gen_phy_mtx %>% dim

# %%
dist.nodes <- function(x){
    x <- reorder(x) # required for the C code
    n <- Ntip(x)
    m <- x$Nnode
    nm <- as.numeric(n + m)

    d <- .C("dist_nodes", 
            as.integer(n), as.integer(m),
            as.integer(x$edge[, 1] - 1L), as.integer(x$edge[, 2] - 1L),
            as.double(x$edge.length), as.integer(Nedge(x)),
            double(nm * nm), NAOK = TRUE)[[7]]
    dim(d) <- c(nm, nm)
    dimnames(d) <- list(1:nm, 1:nm)
    d
}

cophenetic.phylo <- function(x){
    n <- length(x$tip.label)
    ans <- dist.nodes(x)[1:n, 1:n]
    dimnames(ans)[1:2] <- list(x$tip.label)
    ans
}

# %%
# mantel
genPhy_trtJac_mantel = ape::mantel.test(phy2cophenetic(gen_phy), 
                                        phy2cophenetic(trt_jac),
                                        nperm=9)
genPhy_trtJac_mantel

# %% [markdown]
# ## cospeciation
#
# * Testing if the genome phylogeny & trait dendrogram are significantly congruent

# %%
# genome-phylo versus traits-majority-votes
genPhy_trtJac_coSpec = phytools::cospeciation(gen_phy, trt_jac, distance=c('RF'),
                                              method=c('permutation'), 
                                              assoc=NULL, nsim=100)

genPhy_trtJac_coSpec
# Out:
# Co-speciation test based on RF distance.
# P-value obtained via permutation .
#
#    RF distance: 44380
#    Mean(SD) from null: 46713.8(0.7)
#    P-value: 0.009901

# %%
# genome-phylo versus traits-single-votes
genPhy_trtBray_coSpec = phytools::cospeciation(gen_phy, trt_bray, distance=c('RF'),
                                              method=c('permutation'), 
                                              assoc=NULL, nsim=100)

genPhy_trtBray_coSpec
# Out:
# Co-speciation test based on RF distance.
# P-value obtained via permutation .
#
#    RF distance: 41596
#    Mean(SD) from null: 46713.4(1)
#    P-value: 0.009901

# %%
# traits versus traits
trtBray_trtJac_coSpec = phytools::cospeciation(trt_jac, trt_bray, distance=c('RF'),
                                              method=c('permutation'), 
                                              assoc=NULL, nsim=100)

trtBray_trtJac_coSpec
# Out:
# Co-speciation test based on RF distance.
# P-value obtained via permutation .
#
#    RF distance: 40990
#    Mean(SD) from null: 46713.5(1)
#    P-value: 0.009901

# %% [markdown]
# ## Procrustes

# %%
# converting phylogeny to ultrametric dendrogram to distance matrix
force_ultra = function(x){
    phytools::force.ultrametric(x,  method=c("extend"))
}

#' tree to distance matrix
phy2cophenetic = function(phy, tips_to_keep=NULL){
    if(!is.null(tips_to_keep)){
        phy = ape::drop.tip(phy, setdiff(phy$tip.label, tips_to_keep))
    }
    x = phy %>%
        unroot %>%
        multi2di %>%
        cophenetic 
}

# test
x = phy2cophenetic(rtree(10), c('t1', 't2', 't3'))
x
# Out:
#    t2       t1       t3
# t2 0.000000 5.380251 5.131745
# t1 5.380251 0.000000 3.487170
# t3 5.131745 3.487170 0.000000

# %%
#' procrustes on subsets of the data
procrustes_perm = function(permID, phy1, phy2, ntaxa=10){
    to_keep = base::sample(phy1$tip.label, ntaxa)
    x = vegan::procrustes(phy2cophenetic(phy1, to_keep), 
                      phy2cophenetic(phy2, to_keep),
                      symmetric=TRUE) %>% 
        residuals %>%
        as.data.frame
    colnames(x) = 'Residuals'
    x$Taxon = rownames(x)
    return(x)
}

# %%
# setting cluster resources 
resources = list(h_rt = '24:00:00',
                 h_vmem = '8G',
                 threads = '6',
                 conda.env = '/ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy')
plan(batchtools_sge, resources=resources, workers=100)

# %%
# running permutations on the cluster
nperm = 1000
proc_perms = nperm %>%
    seq %>% as.list() %>%
    future_map(procrustes_perm, phy1=gen_phy, phy2=trt_jac, ntaxa=5000) %>%
    data.table::rbindlist(use.names=TRUE, idcol='perm')
                
proc_perms
# Out:
#         perm Residuals  Taxon
# 1       1    0.01407830 GCA_900111935.1
# 2       1    0.01348891 GCA_001564205.1
# ⋮       ⋮    ⋮          ⋮
# 4999999 1000 0.01987195 GCA_003153935.1
# 5000000 1000 0.01259310 GCA_900321865.1

# %%
# saving results
proc_perms_file = file.path(work_dir, 'tree-trait_procrustes_perms.qs')
qs::qsave(proc_perms, proc_perms_file, nthreads=threads)
cat('File written:', proc_perms_file, '\n')
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/phy-trt_comp//tree-trait_procrustes_perms.qs

# %%
#send_email('http://127.0.0.1:9702/notebooks/ipynb/01_data_explore/05_phylo_trait_tree_compare.ipynb')

# %%
# #' pulling out procrustes residuals
# resid_to_df = function(x){
#     x = x %>% residuals %>% as.data.frame
#     colnames(x) = 'Residuals'
#     x$Taxon = rownames(x)
#     return(x)
# }

# # processing permutations in parallel
# doParallel::registerDoParallel(threads)
# proc_perms_res = proc_perms %>%
#     plyr::llply(resid_to_df, .parallel=TRUE) %>%
#     data.table::rbindlist(use.names=TRUE, idcol='Permutation') %>%
#     dt_summarize(n = length(Residuals),
#                  min_res = min(Residuals),
#                  mean_res = mean(Residuals),
#                  sd_res = sd(Residuals),
#                  max_res = max(Residuals),
#                  by=list(Taxon))
    
# proc_perms_res

# %%
# checking key overlap
overlap(proc_perms, meta, Taxon, ncbi_genbank_assembly_accession)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %%
# adding genome info
proc_perms_j = proc_perms %>%
    dt_summarize(n = length(Residuals),
                 min_res = min(Residuals),
                 mean_res = mean(Residuals),
                 sd_res = sd(Residuals),
                 max_res = max(Residuals),
                 by=list(Taxon)) %>%
    inner_join(meta %>% dt_rename('Taxon' = ncbi_genbank_assembly_accession), 
               by=c('Taxon'))

proc_perms_j
# Out:
#       Taxon           n   min_res     mean_res    sd_res       max_res
# 1     GCA_900111935.1 210 0.01337639  0.01462884  0.0005663085 0.01659856
# 2     GCA_001564205.1 234 0.01256048  0.01400108  0.0006123260 0.01623864
# ⋮     ⋮               ⋮   ⋮           ⋮           ⋮            ⋮
# 23359 GCA_003011125.1 204 0.007713498 0.008213922 0.0002683186 0.008874068
# 23360 GCA_000971975.1 198 0.010432801 0.013119199 0.0009732635 0.014707072
#       GTDB_accession
# 1     RS_GCF_900111935.1
# 2     GB_GCA_001564205.1
# ⋮     ⋮
# 23359 RS_GCF_003011125.1
# 23360 RS_GCF_000971975.1
#       ncbi_organism_name                                       Domain
# 1     RS_GCF_900111935.1_Halorubrum sodomense                  d__Archaea
# 2     GB_GCA_001564205.1_Nanohaloarchaea archaeon PL-Br10_U2g5 d__Archaea
# ⋮     ⋮                                                        ⋮
# 23359 RS_GCF_003011125.1_Candidatus Synechococcus lacustris    d__Bacteria
# 23360 RS_GCF_000971975.1_Paenibacillus algorifonticola         d__Bacteria
#       Phylum           Class             Order              Family
# 1     p__Halobacterota c__Halobacteria   o__Halobacteriales f__Haloferacaceae
# 2     p__Halobacterota c__Halobacteria   o__Halobacteriales f__Haloferacaceae
# ⋮     ⋮                ⋮                 ⋮                  ⋮
# 23359 p__Cyanobacteria c__Cyanobacteriia o__Synechococcales f__Cyanobiaceae
# 23360 p__Firmicutes_I  c__Bacilli_A      o__Paenibacillales f__Paenibacillaceae
#       Genus              Species
# 1     g__Halorubrum      s__Halorubrum sodomense
# 2     g__Halorubrum      s__Halorubrum sp001564205
# ⋮     ⋮                  ⋮
# 23359 g__Synechococcus_D s__Synechococcus_D lacustris
# 23360 g__Paenibacillus_C s__Paenibacillus_C algorifonticola

# %%
# summarizing
proc_perms_j_s = proc_perms_j %>%
    dt_mutate(Domain = gsub('^d__', '', Domain), 
              Phylum = gsub('^p__', '', Phylum),
              phylum_mean_res = mean(mean_res),
              n_genomes = n_distinct(Taxon),
              by=list(Domain, Phylum)) %>%
    dt_filter(n_genomes >= 10) %>%
    dt_mutate(Phylum = Phylum %>% reorder(-phylum_mean_res))

p = proc_perms_j_s %>%
    ggplot(aes(Phylum, mean_res, color=Domain)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(y='Procrustes residuals') +
    theme_bw() +
    coord_flip()

p.dims(4.5,7)
Plot(p)
# Out:
# File written: /ebio/abt3_projects/small_projects/nyoungblut/public_data_retireval/ipynb/01_data_explore/.figures/c5013cab645c3b9070d886db59756896.RDS
# plot without title

# %%
p = proc_perms_j_s %>%
    dt_filter(Phylum == 'Euryarchaeota') %>%
    dt_mutate(Taxonomy = paste(Order, Family, Genus, sep=';'),
              Taxonomy = gsub('[ofg]__', '', Taxonomy)) %>%
    dt_mutate(Class = gsub('^c__', '', Class),
              tax_mean_res = mean(mean_res),
              n_genomes = n_distinct(Taxon),
              by=list(Taxonomy)) %>%
    dt_filter(n_genomes >= 3) %>%
    dt_mutate(Taxonomy = Taxonomy %>% reorder(tax_mean_res)) %>%
    ggplot(aes(Taxonomy, mean_res, color=Class)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Order;Family;Genus', y='Procrustes residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip()

p.dims(7.5,3.5)
plot(p)
# Out:
# plot without title

# %%
p = proc_perms_j_s %>%
    dt_filter(Phylum == 'Proteobacteria') %>%
    dt_mutate(Taxonomy = paste(Order, Family, sep=';'),
              Taxonomy = gsub('[ofg]__', '', Taxonomy)) %>%
    dt_mutate(Class = gsub('^c__', '', Class),
              tax_mean_res = mean(mean_res),
              n_genomes = n_distinct(Taxon),
              by=list(Taxonomy)) %>%
    dt_filter(n_genomes >= 10) %>%
    dt_mutate(Taxonomy = Taxonomy %>% reorder(tax_mean_res)) %>%
    ggplot(aes(Taxonomy, mean_res, color=Class)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Order;Family', y='Procrustes residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1),
        axis.text.y = element_text(size=7)
    ) +
    coord_flip()

p.dims(6,7.5)
plot(p)
# Out:
# plot without title

# %%
p = proc_perms_j_s %>%
    dt_filter(Phylum == 'Firmicutes') %>%
    dt_mutate(Taxonomy = paste(Order, Family, sep=';'),
              Taxonomy = gsub('[ofg]__', '', Taxonomy)) %>%
    dt_mutate(Class = gsub('^c__', '', Class),
              tax_mean_res = mean(mean_res),
              n_genomes = n_distinct(Taxon),
              by=list(Taxonomy)) %>%
    dt_filter(n_genomes >= 10) %>%
    dt_mutate(Taxonomy = Taxonomy %>% reorder(tax_mean_res)) %>%
    ggplot(aes(Taxonomy, mean_res, color=Class)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Order;Family', y='Procrustes residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip()

p.dims(6,5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.1 ape_5.3           ggplot2_3.2.1     tidyr_1.0.0
# [5] dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-3            phangorn_2.5.5          gtools_3.8.1
#  [4] tidyselect_0.2.5        repr_1.0.2              purrr_0.3.3
#  [7] lattice_0.20-38         phytools_0.6-99         colorspace_1.4-1
# [10] vctrs_0.2.1             expm_0.999-4            htmltools_0.4.0
# [13] base64enc_0.1-3         rlang_0.4.2             pillar_1.4.3
# [16] glue_1.3.1              withr_2.1.2             uuid_0.1-2
# [19] lifecycle_0.1.0         munsell_0.5.0           combinat_0.0-8
# [22] gtable_0.3.0            coda_0.19-3             evaluate_0.14
# [25] parallel_3.6.2          IRdisplay_0.7.0         Rcpp_1.0.3
# [28] scales_1.1.0            backports_1.1.5         plotrix_3.7-7
# [31] IRkernel_1.1            clusterGeneration_1.3.4 scatterplot3d_0.3-41
# [34] jsonlite_1.6            fastmatch_1.1-0         mnormt_1.5-6
# [37] digest_0.6.23           stringi_1.4.5           animation_2.6
# [40] numDeriv_2016.8-1.1     grid_3.6.2              quadprog_1.5-8
# [43] tools_3.6.2             magrittr_1.5            maps_3.3.0
# [46] lazyeval_0.2.2          tibble_2.1.3            crayon_1.3.4
# [49] pkgconfig_2.0.3         zeallot_0.1.0           ellipsis_0.3.0
# [52] MASS_7.3-51.5           Matrix_1.2-18           assertthat_0.2.1
# [55] R6_2.4.1                igraph_1.2.4.2          nlme_3.1-143
# [58] compiler_3.6.2
