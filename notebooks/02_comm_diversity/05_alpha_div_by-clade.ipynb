# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Metadata" data-toc-modified-id="Metadata-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Metadata</a></span></li><li><span><a href="#Trees" data-toc-modified-id="Trees-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Trees</a></span></li><li><span><a href="#Bracken-counts" data-toc-modified-id="Bracken-counts-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Bracken counts</a></span><ul class="toc-item"><li><span><a href="#Joining" data-toc-modified-id="Joining-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Joining</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#Calc-alpha-div-per-clade" data-toc-modified-id="Calc-alpha-div-per-clade-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Calc alpha div per clade</a></span></li><li><span><a href="#lmer:-full-dataset" data-toc-modified-id="lmer:-full-dataset-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>lmer: full dataset</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Plotting</a></span></li></ul></li><li><span><a href="#lmer:-westernized-+-age-+-gender" data-toc-modified-id="lmer:-westernized-+-age-+-gender-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>lmer: westernized + age + gender</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Plotting</a></span></li></ul></li><li><span><a href="#lmer:-westernized-+-age-+-gender-+-disease" data-toc-modified-id="lmer:-westernized-+-age-+-gender-+-disease-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>lmer: westernized + age + gender + disease</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Plotting</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Investigate which specific clades differ most by westernization, gender, etc in regards to diversity

# %% [markdown]
# # Var

# %%
# working dir
work_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/'

# bracken counts
brk_file = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/bracken_filt.qs'

# metadata
## filtered
metadata_filt_file = file.path(work_dir, 'CurMetDat_metadata_filt-n1846.tsv')
## all 
base_in_dir = '/ebio/abt3_projects/small_projects/nyoungblut/public_data_retireval/'
metadata_file = file.path(base_in_dir, 'CurMetDat-metagenomes', 'files', 'metadata', 'Filtered_CurMetDat_f.tsv')

# ref genome metadata (GTDBr89 metadata)
genome_meta_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/metadata_1per-GTDB-Spec_gte50comp-lt5cont_wtaxID_wPath.tsv'

# metagenome profiling dir
profile_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/LLMGP/'

# phylogeny
phy_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/phylogeny/ar122-bac120_r89_1per-GTDB-Spec_gte50comp-lt5cont_rn.nwk'
## Trait 
phy_trt_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/predictions_flat_majority-votes_combined_jaccard_rn.nwk'
## COG content
phy_cog_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/genes-per-COG_UniRef90_bray.nwk'
phy_cogcat_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/genes-per-COGcat_UniRef90_bray.nwk'
## pfam content
phy_pfam_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/genes-per-pfam_UniRef90_bray.nwk'
phy_pfamcat_file = '/ebio/abt3_projects/databases_no-backup/GTDB/release89/LLMGP-DB/genomes/LLG/phenotype/genes-per-pfamGrp_UniRef90_bray.nwk'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(tidytable)
library(ape)
library(phyloseq)
library(vegan)
library(PhyloMeasures)
library(lme4)
library(lmerTest)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt
#
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.5-6
#
# Warning message:
# “package ‘lme4’ was built under R version 3.6.3”
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
make_dir(work_dir)
setDTthreads(threads)
df.dims()
# Out:
# Directory already exists: /ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/diversity/

# %% [markdown]
# # Load

# %% [markdown]
# ## Metadata

# %%
# all 
meta = fread(metadata_file, sep='\t', check.names=TRUE) %>%
    mutate.(Sample = gsub('-', '.', Sample)) %>%
    filter.(number_reads >= 5e5) %>%
    mutate.(disease_status = ifelse(disease != 'healthy', 'diseased', disease)) %>%
    select.(Sample, dataset_name, subjectID, study_condition, 
              disease, disease_status, age, gender, BMI, westernized)

meta %>% unique_n('Samples', Sample)
meta
# Out:
# No. of unique Samples: 3582
#      Sample              dataset_name  subjectID study_condition disease
# 1    MV_FEM1_t1Q14       AsnicarF_2017 MV_FEM1   control         healthy
# 2    MV_FEM2_t1Q14       AsnicarF_2017 MV_FEM2   control         healthy
# ⋮    ⋮                   ⋮             ⋮         ⋮               ⋮
# 3581 CCIS82944710ST.20.0 ZellerG_2014  FR-730    control         healthy
# 3582 CCIS93040568ST.20.0 ZellerG_2014  FR-682    control         healthy
#      disease_status age gender BMI westernized
# 1    healthy        NA  female NA  TRUE
# 2    healthy        NA  female NA  TRUE
# ⋮    ⋮              ⋮   ⋮      ⋮   ⋮
# 3581 healthy        38  female 22  TRUE
# 3582 healthy        65  male   30  TRUE

# %%
# filtered metadata
meta_f = fread(metadata_filt_file, sep='\t') %>%
    mutate.(Sample = gsub('-', '.', Sample)) %>%
    filter.(number_reads >= 5e5) %>%
    select.(Sample, dataset, subjectID, study_condition, 
              disease, age, gender, BMI, westernized)

meta_f %>% unique_n('Samples', Sample)
meta_f
# Out:
# No. of unique Samples: 1802
#      Sample      dataset               subjectID     study_condition disease
# 1    TRAVELRES1  Bengtsson-PalmeJ_2015 TRAVELRES1_2  control         healthy
# 2    TRAVELRES10 Bengtsson-PalmeJ_2015 TRAVELRES9_10 control         healthy
# ⋮    ⋮           ⋮                     ⋮             ⋮               ⋮
# 4264 YEZ_N.38    YeZ_2018              YEZ_N-38      control         healthy
# 4265 YEZ_N.37    YeZ_2018              YEZ_N-37      control         healthy
#      age gender BMI  westernized
# 1    25  female NA   TRUE
# 2    34  female NA   TRUE
# ⋮    ⋮   ⋮      ⋮    ⋮
# 4264 38  female 19.7 TRUE
# 4265 46  male   29.7 TRUE

# %%
# genome metadata
tax_levs = c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species')
genome_meta = fread(genome_meta_file, sep='\t') %>%
    select.(ncbi_genbank_assembly_accession, ncbi_organism_name, gtdb_taxonomy, accession) %>%
    rename.('GTDB_accession' = accession) %>%
    separate.(gtdb_taxonomy, tax_levs, sep=';') %>%
    mutate.(Species = gsub(' ', '_', Species))

genome_meta %>% unique_n('accessions', ncbi_genbank_assembly_accession)
genome_meta
# Out:
# No. of unique accessions: 23360
#       ncbi_genbank_assembly_accession
# 1     GCA_002789635.1
# 2     GCA_001784635.1
# ⋮     ⋮
# 23359 GCA_001775395.1
# 23360 GCA_002791595.1
#       ncbi_organism_name
# 1     GB_GCA_002789635.1_Candidatus Aenigmarchaeota archaeon CG_4_9_14_3_um_filter_37_18
# 2     GB_GCA_001784635.1_Candidatus Micrarchaeota archaeon RBG_16_49_10
# ⋮     ⋮
# 23359 GB_GCA_001775395.1_candidate division Zixibacteria bacterium RBG_16_53_22
# 23360 GB_GCA_002791595.1_candidate division Zixibacteria bacterium CG_4_9_14_3_um_filter_46_8
#       GTDB_accession     Domain      Phylum             Class
# 1     GB_GCA_002789635.1 d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia
# 2     GB_GCA_001784635.1 d__Archaea  p__Aenigmarchaeota c__Aenigmarchaeia
# ⋮     ⋮                  ⋮           ⋮                  ⋮
# 23359 GB_GCA_001775395.1 d__Bacteria p__Zixibacteria    c__MSB-5A5
# 23360 GB_GCA_002791595.1 d__Bacteria p__Zixibacteria    c__MSB-5A5
#       Order             Family            Genus
# 1     o__CG10238-14     f__CG10238-14     g__CG10238-14
# 2     o__CG10238-14     f__CG10238-14     g__RBG-16-49-10
# ⋮     ⋮                 ⋮                 ⋮
# 23359 o__UBA10806       f__UBA10806       g__UBA10806
# 23360 o__UM-FILTER-46-8 f__UM-FILTER-46-8 g__UM-FILTER-46-8
#       Species
# 1     s__CG10238-14_sp002789635
# 2     s__RBG-16-49-10_sp001784635
# ⋮     ⋮
# 23359 s__UBA10806_sp001775395
# 23360 s__UM-FILTER-46-8_sp002791595

# %% [markdown]
# ## Trees

# %%
# Genome phylogeny
gtdb_phy = read.tree(phy_file)
gtdb_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	s__Halorubrum_sp000296615, s__Halorubrum_distributum, s__Halorubrum_trapanicum, s__Halorubrum_tropicale, s__Halorubrum_coriense, s__Halorubrum_ezzemoulense, ...
# Node labels:
# 	100.0, d__Archaea100.0, 97.0, 99.0, 100.0, 100.0-p__Halobacterota, ...
#
# Rooted; includes branch lengths.

# %%
# traitar trait dendrogram
trt_phy = read.tree(phy_trt_file)
trt_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	s__Mikella_endobia, s__Prochlorococcus_B_sp003284185, s__Prochlorococcus_A_sp003282425, s__Eperythrozoon_A_wenyonii_A, s__GN02-872_sp003260325, s__SZUA-486_sp003251635, ...
#
# Rooted; includes branch lengths.

# %%
# cog dendrogram
cog_phy = read.tree(phy_cog_file)
cog_phy
# Out:
# Phylogenetic tree with 23360 tips and 23359 internal nodes.
#
# Tip labels:
# 	s__UBA9959_sp001799795, s__2-02-FULL-45-21_sp001805845, s__UBA11600_sp002717745, s__UBA11600_sp002714165, s__UBA11600_sp002730735, s__LS-NOB_sp002705185, ...
#
# Rooted; includes branch lengths.

# %%
# pfam dendrogram
pfam_phy = read.tree(phy_pfam_file)
pfam_phy
# Out:
# Phylogenetic tree with 23358 tips and 23357 internal nodes.
#
# Tip labels:
# 	s__Acinetobacter_gerneri, s__Enterococcus_sp002174455, s__Cnuella_takakiae, s__Marinomonas_primoryensis, s__Kosakonia_oryzendophytica, s__Roseomonas_cervicalis, ...
#
# Rooted; includes branch lengths.

# %%
# checking key overlap
overlap(gtdb_phy$tip.label, trt_phy$tip.label)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %%
# checking key overlap
overlap(gtdb_phy$tip.label, cog_phy$tip.label)
# Out:
# intersect(x,y): 23360
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 23360

# %%
# checking key overlap
overlap(gtdb_phy$tip.label, pfam_phy$tip.label)
# Out:
# intersect(x,y): 23358
# setdiff(x,y): 2
# setdiff(y,x): 0
# union(x,y): 23360

# %% [markdown]
# ## Bracken counts

# %%
# reading in bracken counts
brk_cls = qs::qread(brk_file, nthreads=threads) %>%
    as.data.table %>%
    mutate.(name = name %>% gsub(' ', '_', .))
brk_cls
# Out:
#         dataset       name                         taxonomy_id taxonomy_lvl
# 1       CosteaPI_2017 s__Caecibacter_massiliensis  108259      S
# 2       CosteaPI_2017 s__UBA1777_sp002350825       178550      S
# ⋮       ⋮             ⋮                            ⋮           ⋮
# 4934811 YuJ_2015      s__Serratia_grimesii         121568      S
# 4934812 YuJ_2015      s__Bacteroides_A_sp002161565 119189      S
#         Domain   Phylum         Class               Order
# 1       Bacteria Firmicutes_C   Negativicutes       Veillonellales
# 2       Bacteria Firmicutes_A   Clostridia          Oscillospirales
# ⋮       ⋮        ⋮              ⋮                   ⋮
# 4934811 Bacteria Proteobacteria Gammaproteobacteria Enterobacterales
# 4934812 Bacteria Bacteroidota   Bacteroidia         Bacteroidales
#         Family             Genus         Species
# 1       Megasphaeraceae    Caecibacter   Caecibacter massiliensis
# 2       Oscillospiraceae   UBA1777       UBA1777 sp002350825
# ⋮       ⋮                  ⋮             ⋮
# 4934811 Enterobacteriaceae Serratia      Serratia grimesii
# 4934812 Bacteroidaceae     Bacteroides_A Bacteroides_A sp002161565
#         Sample           Abundance
# 1       halbarad.11.0.0  0
# 2       halbarad.11.0.0  0
# ⋮       ⋮                ⋮
# 4934811 SZAXPI017592.142 0
# 4934812 SZAXPI017592.142 0

# %%
# overlap with ref genome metadata
overlap(brk_cls, genome_meta, name, Species)
# Out:
# intersect(x,y): 3550
# setdiff(x,y): 0
# setdiff(y,x): 19810
# union(x,y): 23360

# %%
# overlap with sample IDs
overlap(brk_cls, meta, Sample, Sample)
# Out:
# intersect(x,y): 3348
# setdiff(x,y): 9
# setdiff(y,x): 234
# union(x,y): 3591

# %%
# overlap with sample IDs
overlap(brk_cls, meta_f, Sample, Sample)
# Out:
# intersect(x,y): 1799
# setdiff(x,y): 1558
# setdiff(y,x): 3
# union(x,y): 3360

# %%
# checking overlap with phylogeny tip labels
overlap(brk_cls, gtdb_phy$tip.label, name)
# Out:
# intersect(x,y): 3550
# setdiff(x,y): 0
# setdiff(y,x): 19810
# union(x,y): 23360

# %% [markdown]
# ### Joining

# %%
# just overlapping samples with metadata
brk_cls = brk_cls %>%
    inner_join.(meta %>% rename.('dataset' = dataset_name), 
                by=c('Sample', 'dataset'))

brk_cls %>% unique_n('Samples', Sample)
brk_cls
# Out:
# No. of unique Samples: 3348
#         dataset       name                       taxonomy_id taxonomy_lvl
# 1       AsnicarF_2017 s__UBA1777_sp002350825     178550      S
# 2       AsnicarF_2017 s__Hespellia_stercorisuis  173762      S
# ⋮       ⋮             ⋮                          ⋮           ⋮
# 4923435 ZeeviD_2015   s__UBA2813_sp900319365     118664      S
# 4923436 ZeeviD_2015   s__Bifidobacterium_subtile 131154      S
#         Domain   Phylum           Class            Order
# 1       Bacteria Firmicutes_A     Clostridia       Oscillospirales
# 2       Bacteria Firmicutes_A     Clostridia       Lachnospirales
# ⋮       ⋮        ⋮                ⋮                ⋮
# 4923435 Bacteria Cyanobacteria    Vampirovibrionia Gastranaerophilales
# 4923436 Bacteria Actinobacteriota Actinobacteria   Actinomycetales
#         Family               Genus           ⋯ Sample            Abundance
# 1       Oscillospiraceae     UBA1777         ⋯ MV_FEM1_t1Q14     0
# 2       Lachnospiraceae      Hespellia       ⋯ MV_FEM1_t1Q14     0
# ⋮       ⋮                    ⋮               ⋱ ⋮                 ⋮
# 4923435 Gastranaerophilaceae UBA2813         ⋯ PNP_Validation_46 0
# 4923436 Bifidobacteriaceae   Bifidobacterium ⋯ PNP_Validation_46 0
#         subjectID         study_condition disease disease_status age gender BMI
# 1       MV_FEM1           control         healthy healthy        NA  female NA
# 2       MV_FEM1           control         healthy healthy        NA  female NA
# ⋮       ⋮                 ⋮               ⋮       ⋮              ⋮   ⋮      ⋮
# 4923435 PNP_Validation_46 control         healthy healthy        NA  NA     NA
# 4923436 PNP_Validation_46 control         healthy healthy        NA  NA     NA
#         westernized
# 1       TRUE
# 2       TRUE
# ⋮       ⋮
# 4923435 TRUE
# 4923436 TRUE

# %% [markdown]
# ## Summary

# %%
# summary
brk_cls %>% unique_n('taxa', name)
# Out:
# No. of unique taxa: 3550

# %%
# summary
brk_cls %>% unique_n('samples', Sample)
# Out:
# No. of unique samples: 3348

# %%
# summary
brk_cls %>% unique_n('samples', Phylum)
# Out:
# No. of unique samples: 37

# %% [markdown]
# # Calc alpha div per clade

# %%
# wrapper for calculating Faith's PD
calc_pd = function(tree, df){
    df %>% 
        apply(2, function(x) ifelse(is.na(x) | x <= 0, 0, 1)) %>%
        PhyloMeasures::pd.query(tree, ., standardize = FALSE, null.model="uniform", 
                                reps=100, seed=3982)
}

# %%
calc_alpha_div = function(df){
    # making matrix 
    brk_cls_w = df %>%
        select.(name, Abundance, Sample) %>%
        pivot_wider.(id_cols=Sample, names_from=name, values_from=Abundance) %>%
        as_tibble %>%
        mutate_if(is.numeric, function(x) ifelse(is.na(x), 0, x)) %>%
        as.data.frame
    
    rownames(brk_cls_w) = brk_cls_w$Sample
    brk_cls_w$Sample = NULL
    clade = df %>% slice_head.(n=1) %>% 
       mutate.(Clade = paste(Domain, Phylum, Class, Order, Family, sep='___')) %>% 
       pull.(Clade)
    
    # calculating alpha diversity for all samples
    alpha_div = data.frame(
        Sample = rownames(brk_cls_w),
        Clade = clade,
        nobs = brk_cls_w %>% apply(1, function(x) sum(x > 0)) %>% as.vector,
        shannon = vegan::diversity(brk_cls_w) %>% as.vector,
        pd_phy = calc_pd(gtdb_phy, brk_cls_w) %>% as.vector,  # phylogeny
        pd_trt = calc_pd(trt_phy, brk_cls_w) %>% as.vector,    # traits
        pd_cog = calc_pd(cog_phy, brk_cls_w) %>% as.vector,    # cog
        pd_pfam = calc_pd(pfam_phy, brk_cls_w) %>% as.vector    # pfam
    )
    return(alpha_div)
}

# %%
# splitting by group
doParallel::registerDoParallel(threads)
alpha_div = brk_cls %>%
    mutate.(n_spec = n_distinct(Species), 
            .by=c(Domain, Phylum, Class, Order, Family, Genus)) %>%
    filter(n_spec > 1) %>%
    group_split(Domain, Phylum, Class, Order, Family) %>%
    plyr::llply(calc_alpha_div, .parallel=TRUE) %>%
    data.table::rbindlist(use.names=TRUE)

alpha_div %>% unique_n('Clades', Clade)
alpha_div
# Out:
# No. of unique Clades: 136
#        Sample
# 1      A01_02_1FE
# 2      A02_01_1FE
# ⋮      ⋮
# 308765 nHMX11726
# 308766 scavenger.11.60.0
#        Clade
# 1      Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# 2      Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# ⋮      ⋮
# 308765 Bacteria___Verrucomicrobiota___Verrucomicrobiae___Verrucomicrobiales___Akkermansiaceae
# 308766 Bacteria___Verrucomicrobiota___Verrucomicrobiae___Verrucomicrobiales___Akkermansiaceae
#        nobs shannon pd_phy pd_trt pd_cog pd_pfam
# 1      0    0       0      0      0      0
# 2      0    0       0      0      0      0
# ⋮      ⋮    ⋮       ⋮      ⋮      ⋮      ⋮
# 308765 1    0       0      0      0      0
# 308766 0    0       0      0      0      0

# %%
# formatting and adding metadata
alpha_div = alpha_div %>%
    pivot_longer.(cols = c(-Sample, -Clade), 
                    names_to=c('Metric'), 
                    values_to=c('Metric_value')) %>%
    inner_join.(meta, by=c('Sample')) 

alpha_div %>% unique_n('Clades', Clade)
alpha_div %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('Metrics', Metric)
alpha_div
# Out:
# Warning message in melt.data.table(data = .df, id.vars = id_vars, measure.vars = cols, :
# “'measure.vars' [nobs, shannon, pd_phy, pd_trt, ...] are not all of the same type. By order of hierarchy, the molten data value column will be of type 'double'. All measure variables not of type 'double' will be coerced too. Check DETAILS in ?melt.data.table for more on coercion.”
# No. of unique Clades: 136
# No. of unique Samples: 3348
# No. of unique Metrics: 6
#         Sample
# 1       MV_FEM1_t1Q14
# 2       MV_FEM1_t1Q14
# ⋮       ⋮
# 1852595 PNP_Validation_46
# 1852596 PNP_Validation_46
#         Clade
# 1       Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# 2       Bacteria___Actinobacteriota___Actinobacteria___Actinomycetales___Actinomycetaceae
# ⋮       ⋮
# 1852595 Bacteria___Verrucomicrobiota___Verrucomicrobiae___Opitutales___CAG-312
# 1852596 Bacteria___Verrucomicrobiota___Verrucomicrobiae___Verrucomicrobiales___Akkermansiaceae
#         Metric  Metric_value dataset_name  subjectID         study_condition
# 1       nobs    1            AsnicarF_2017 MV_FEM1           control
# 2       nobs    0            AsnicarF_2017 MV_FEM1           control
# ⋮       ⋮       ⋮            ⋮             ⋮                 ⋮
# 1852595 pd_pfam 0            ZeeviD_2015   PNP_Validation_46 control
# 1852596 pd_pfam 0            ZeeviD_2015   PNP_Validation_46 control
#         disease disease_status age gender BMI westernized
# 1       healthy healthy        NA  female NA  TRUE
# 2       healthy healthy        NA  female NA  TRUE
# ⋮       ⋮       ⋮              ⋮   ⋮      ⋮   ⋮
# 1852595 healthy healthy        NA  NA     NA  TRUE
# 1852596 healthy healthy        NA  NA     NA  TRUE

# %%
# summary of measures
alpha_div$Metric %>% table
# Out:
# .
#    nobs  pd_cog pd_pfam  pd_phy  pd_trt shannon
#  308766  308766  308766  308766  308766  308766

# %% [markdown]
# # lmer: full dataset

# %%
calc_lm = function(x, alpha_div, Form = 'Metric_value ~ westernized + (1 | dataset_name)'){
    Form = as.formula(Form)
    x = x %>% as.matrix
    clade = x[1,'Clade'] %>% as.character 
    metric = x[1,'Metric'] %>% as.character 
    clade = enexpr(clade)
    metric = enexpr(metric)
    alpha_div = alpha_div %>%
        filter.(Clade == !!clade) %>%
        filter.(Metric == !!metric) %>%
        mutate.(age = log2(age)) 
    # lmer
    fm = tryCatch({
        lmer(Form, data=alpha_div)
    }, error = function(e) {
        NULL
    })
    res = tryCatch({
        anova(fm, type='II') %>% as.data.frame
    }, error = function(e) {
        NULL
    })
    if(is.null(res) || nrow(res) < 1){
        cols = c('Sum Sq', 'Mean Sq', 'NumDF', 'DenDF', 'F value', 'Pr(>F)')
        res = matrix(rep(NA, 6), nrow=1, ncol=6, dimnames=list('westernized', cols))
        res = as.data.frame(res)
    }
    res$Clade = clade
    res$Metric = metric
    res$Variable = rownames(res)
    return(res)
}

# test
F = 'Metric_value ~ westernized + age + gender + (1 | dataset_name)'
df = data.frame('Metric' = c('shannon'), 
                'Clade' = c('Bacteria___Firmicutes_A___Clostridia___Oscillospirales___CAG-272'))
calc_lm(x=df, alpha_div=alpha_div, Form=F)
# Out:
#             Sum Sq     Mean Sq    NumDF DenDF       F value    Pr(>F)
# westernized 1.04915624 1.04915624 1        9.047721 23.8522720 0.0008535315
# age         0.18780541 0.18780541 1      271.180398  4.2697032 0.0397471546
# gender      0.01559209 0.01559209 1     1737.762377  0.3544818 0.5516644971
#             Clade
# westernized Bacteria___Firmicutes_A___Clostridia___Oscillospirales___CAG-272
# age         Bacteria___Firmicutes_A___Clostridia___Oscillospirales___CAG-272
# gender      Bacteria___Firmicutes_A___Clostridia___Oscillospirales___CAG-272
#             Metric  Variable
# westernized shannon westernized
# age         shannon age
# gender      shannon gender

# %%
# pairwise combinations of clade & div_metric
clades = alpha_div %>% pull.(Clade) %>% unique
metrics = alpha_div %>% pull.(Metric) %>% unique
x = expand.grid(metrics, clades) 
colnames(x) = c('Metric', 'Clade')
x$iter = 1:nrow(x)

# calculation
doParallel::registerDoParallel(threads)
lmer_res = x %>% 
    group_split.(iter) %>%
    plyr::llply(calc_lm, alpha_div=alpha_div, .parallel=TRUE) %>%
    data.table::rbindlist(use.names=TRUE)

# formatting
colnames(lmer_res) = c('Sum_sq', 'Mean_sq', 'NumDF', 'DenDF', 
                       'F_value', 'P', 'Clade', 'Metric', 'Variable')
lmer_res = lmer_res %>%
    mutate.(P = P %>% as.Num,
            Padj = p.adjust(P, method='BH'),
            Metric = case_when.(Metric == 'nobs' ~ 'No. of\nobserved',
                                Metric == 'shannon' ~ 'Shannon\nIndex',
                                Metric == 'pd_cog' ~ 'Faith\'s PD\n(cog)',
                                Metric == 'pd_pfam' ~ 'Faith\'s PD\n(pfam)',
                                Metric == 'pd_phy' ~ 'Faith\'s PD\n(phy)',
                                Metric == 'pd_trt' ~ 'Faith\'s PD\n(trt)'))
            

# summary
lmer_res %>% unique_n('Clades', Clade)
lmer_res %>% unique_n('Metrics', Metric)
lmer_res %>% unique_n('Variables', Variable)
lmer_res
# Out:
# No. of unique Clades: 136
# No. of unique Metrics: 6
# No. of unique Variables: 1
#     Sum_sq    Mean_sq   NumDF DenDF    F_value  P
# 1   4.8591114 4.8591114 1     93.84265 4.998572 0.02773883
# 2   0.1724344 0.1724344 1     84.92351 5.230970 0.02467516
# ⋮   ⋮         ⋮         ⋮     ⋮        ⋮        ⋮
# 815 NA        NA        NA    NA       NA       NA
# 816 NA        NA        NA    NA       NA       NA
#     Clade
# 1   Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# 2   Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# ⋮   ⋮
# 815 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
# 816 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
#     Metric             Variable    Padj
# 1   No. of\nobserved   westernized 0.09011863
# 2   Shannon\nIndex     westernized 0.08288936
# ⋮   ⋮                  ⋮           ⋮
# 815 Faith's PD\n(cog)  westernized NA
# 816 Faith's PD\n(pfam) westernized NA

# %%
# Summary of P-values
lmer_res %>% pull.(P) %>% summary_x('P')
lmer_res %>% pull.(Padj) %>% summary_x('Padj')
# Out:
#   Min.         1st Qu.   Median    Mean      3rd Qu.  Max.      NA's sd
# P 1.632775e-16 0.0117568 0.2239191 0.3039617 0.572895 0.9999998 124  46.736
#   sd_err_of_mean
# P 17.664
#      Min.        1st Qu.    Median    Mean     3rd Qu.   Max.      NA's sd
# Padj 1.12988e-13 0.04676573 0.4452644 0.412797 0.7634894 0.9999998 124  46.701
#      sd_err_of_mean
# Padj 17.651

# %% [markdown]
# ## Plotting

# %%
p = lmer_res %>%
    mutate.(any_sig = any(Padj < 0.01), .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=65, hjust=1)
    ) +
    coord_flip() 

p.dims(9.5,5)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    mutate.(any_sig = any(Padj < 0.01), .by=c(Clade)) %>%
    filter.(any_sig == TRUE, Metric != 'nobs') %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
              Clade = gsub('^(Bacteria|Archaea);', '', Clade),
              Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(alpha=0.1, size=2) +
    geom_point(alpha=0.8, shape='O', size=2) +
    scale_color_discrete('Measure') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    theme_bw() +
    coord_flip() 

p.dims(7,4.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # lmer: westernized + age + gender

# %%
# filtering
alpha_div_f = alpha_div %>%
    filter.(!is.na(gender),
            !is.na(age)) %>%
    mutate.(age = log2(age))

alpha_div %>% unique_n('Samples', Sample)
alpha_div_f %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('datasets', dataset_name)
alpha_div_f %>% unique_n('datasets', dataset_name)
# Out:
# No. of unique Samples: 3348
# No. of unique Samples: 1843
# No. of unique datasets: 33
# No. of unique datasets: 17

# %%
# pairwise combinations of clade & div_metric
clades = alpha_div %>% pull.(Clade) %>% unique
metrics = alpha_div %>% pull.(Metric) %>% unique
x = expand.grid(metrics, clades) 
colnames(x) = c('Metric', 'Clade')
x$iter = 1:nrow(x)

# calculation
Form = 'Metric_value ~ westernized + age + gender + (1 | dataset_name)'
doParallel::registerDoParallel(threads)
lmer_res = x %>% 
    group_split.(iter) %>%
    plyr::llply(calc_lm, alpha_div=alpha_div_f, Form=Form, .parallel=TRUE) %>%
    data.table::rbindlist(use.names=TRUE)

# formatting
colnames(lmer_res) = c('Sum_sq', 'Mean_sq', 'NumDF', 'DenDF', 
                       'F_value', 'P', 'Clade', 'Metric', 'Variable')
lmer_res = lmer_res %>%
    mutate.(P = P %>% as.Num,
            Padj = p.adjust(P, method='BH'),
            Metric = case_when.(Metric == 'nobs' ~ 'No. of\nobserved',
                                Metric == 'shannon' ~ 'Shannon\nIndex',
                                Metric == 'pd_cog' ~ 'Faith\'s PD\n(COG)',
                                Metric == 'pd_pfam' ~ 'Faith\'s PD\n(Pfam)',
                                Metric == 'pd_phy' ~ 'Faith\'s PD\n(Phylogeny)',
                                Metric == 'pd_trt' ~ 'Faith\'s PD\n(Trait)'))

# summary
lmer_res %>% unique_n('Clades', Clade)
lmer_res %>% unique_n('Metrics', Metric)
lmer_res
# Out:
# No. of unique Clades: 136
# No. of unique Metrics: 6
#      Sum_sq   Mean_sq  NumDF DenDF     F_value  P
# 1    10.09782 10.09782 1      16.63938  9.59229 6.673986e-03
# 2    32.27509 32.27509 1     455.69933 30.65928 5.203119e-08
# ⋮    ⋮        ⋮        ⋮     ⋮         ⋮        ⋮
# 2091 NA       NA       NA    NA        NA       NA
# 2092 NA       NA       NA    NA        NA       NA
#      Clade
# 1    Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# 2    Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# ⋮    ⋮
# 2091 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
# 2092 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
#      Metric             Variable    Padj
# 1    No. of\nobserved   westernized 4.426814e-02
# 2    No. of\nobserved   age         2.303893e-06
# ⋮    ⋮                  ⋮           ⋮
# 2091 Faith's PD\n(COG)  westernized NA
# 2092 Faith's PD\n(Pfam) westernized NA

# %%
# Summary of P-values
lmer_res %>% pull.(P) %>% summary_x('P')
lmer_res %>% pull.(Padj) %>% summary_x('Padj')
# Out:
#   Min.        1st Qu.   Median    Mean     3rd Qu.   Max. NA's sd
# P 3.15071e-36 0.0389461 0.2488497 0.332004 0.5667331 1    188  70.92
#   sd_err_of_mean
# P 26.805
#      Min.         1st Qu.   Median    Mean      3rd Qu.   Max. NA's sd
# Padj 1.199791e-33 0.1555388 0.4974369 0.4766614 0.7551349 1    188  70.876
#      sd_err_of_mean
# Padj 26.789

# %%
p = lmer_res %>%
    ggplot(aes(F_value, Padj)) +
    geom_point(shape='O') +
    facet_wrap(~ Metric) +
    theme_bw()

p.dims(6,4)
plot(p)
# Out:
# Warning message:
# “Removed 188 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Plotting

# %%
# westernization
p = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'westernized') %>%
    mutate.(sig = Padj < 0.01) %>%
    mutate.(any_sig = any(sig), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value, na.rm=TRUE), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(9.5,5)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'westernized') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(alpha=0.2, size=1.5) +
    geom_point(alpha=0.6, shape='O', size=1.5) +
    scale_color_discrete('Measure') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ sig) +
    theme_bw() +
    coord_flip() 

p.dims(7.5,4.2)
plot(p)
# Out:
# plot without title

# %%
# summary
lmer_res_s = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'westernized') %>%
    filter.(Padj < 0.01) %>%
    mutate.(Clade = gsub('__', ';', Clade)) %>%
    separate.(Clade, c('Domain', 'Phylum', 'Class', 'Order', 'Family'), sep=';')
lmer_res_s$Phylum %>% unique_n('Phyla')
lmer_res_s$Class %>% unique_n('Classes')
lmer_res_s$Order %>% unique_n('Order')
# Out:
# No. of unique Phyla: 9
# No. of unique Classes: 10
# No. of unique Order: 15

# %%
p = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'gender') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(alpha=0.2, size=1.5) +
    geom_point(alpha=0.6, shape='O', size=1.5) +
    scale_color_discrete('Measure') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ sig) +
    theme_bw() +
    coord_flip() 

p.dims(7.5,2.7)
plot(p)
# Out:
# plot without title

# %%
# summary
lmer_res_s = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'gender') %>%
    filter.(Padj < 0.01) %>%
    mutate.(Clade = gsub('__', ';', Clade)) %>%
    separate.(Clade, c('Domain', 'Phylum', 'Class', 'Order', 'Family'), sep=';')
lmer_res_s$Phylum %>% unique_n('Phyla')
lmer_res_s$Class %>% unique_n('Classes')
lmer_res_s$Order %>% unique_n('Order')
# Out:
# No. of unique Phyla: 6
# No. of unique Classes: 6
# No. of unique Order: 6

# %%
p = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'age') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(alpha=0.2, size=1.5) +
    geom_point(alpha=0.6, shape='O', size=1.5) +
    scale_color_discrete('Measure') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ sig) +
    theme_bw() +
    coord_flip() 

p.dims(7.5,2.8)
plot(p)
# Out:
# plot without title

# %%
# summary
lmer_res_s = lmer_res %>%
    filter.(Metric != 'No. of\nobserved') %>%
    filter.(Variable == 'age') %>%
    filter.(Padj < 0.01) %>%
    mutate.(Clade = gsub('__', ';', Clade)) %>%
    separate.(Clade, c('Domain', 'Phylum', 'Class', 'Order', 'Family'), sep=';')
lmer_res_s$Phylum %>% unique_n('Phyla')
lmer_res_s$Class %>% unique_n('Classes')
lmer_res_s$Order %>% unique_n('Order')
# Out:
# No. of unique Phyla: 4
# No. of unique Classes: 5
# No. of unique Order: 8

# %% [markdown]
# # lmer: westernized + age + gender + disease

# %%
# filtering
alpha_div_f = alpha_div %>%
    filter.(!is.na(gender),
              !is.na(age),
              !is.na(disease_status)) %>%
    mutate.(age = log2(age))

alpha_div %>% unique_n('Samples', Sample)
alpha_div_f %>% unique_n('Samples', Sample)
alpha_div %>% unique_n('datasets', dataset_name)
alpha_div_f %>% unique_n('datasets', dataset_name)
# Out:
# No. of unique Samples: 3348
# No. of unique Samples: 1413
# No. of unique datasets: 33
# No. of unique datasets: 15

# %%
# pairwise combinations of clade & div_metric
clades = alpha_div %>% pull.(Clade) %>% unique
metrics = alpha_div %>% pull.(Metric) %>% unique
x = expand.grid(metrics, clades) 
colnames(x) = c('Metric', 'Clade')
x$iter = 1:nrow(x)

# calculation
Form = 'Metric_value ~ westernized + age + gender + disease_status + (1 | dataset_name)'
doParallel::registerDoParallel(threads)
lmer_res = x %>% 
    group_split.(iter) %>%
    plyr::llply(calc_lm, alpha_div=alpha_div_f, Form=Form, .parallel=TRUE) %>%
    data.table::rbindlist(use.names=TRUE)

# formatting
colnames(lmer_res) = c('Sum_sq', 'Mean_sq', 'NumDF', 'DenDF', 
                       'F_value', 'P', 'Clade', 'Metric', 'Variable')
lmer_res = lmer_res %>%
    mutate.(P = P %>% as.Num,
              Padj = p.adjust(P, method='BH'))

# summary
lmer_res %>% unique_n('Clades', Clade)
lmer_res %>% unique_n('Metrics', Metric)
lmer_res
# Out:
# No. of unique Clades: 136
# No. of unique Metrics: 6
#      Sum_sq    Mean_sq   NumDF DenDF     F_value  P
# 1     7.205384  7.205384 1      20.17798 11.41098 2.961303e-03
# 2    15.104289 15.104289 1     844.97100 23.92026 1.201996e-06
# ⋮    ⋮         ⋮         ⋮     ⋮         ⋮        ⋮
# 2459 NA        NA        NA    NA        NA       NA
# 2460 NA        NA        NA    NA        NA       NA
#      Clade
# 1    Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# 2    Archaea___Euryarchaeota___Methanobacteria___Methanobacteriales___Methanobacteriaceae
# ⋮    ⋮
# 2459 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
# 2460 Bacteria___Firmicutes_A___Clostridia___Saccharofermentanales___Saccharofermentanaceae
#      Metric  Variable    Padj
# 1    nobs    westernized 2.227104e-02
# 2    nobs    age         2.912836e-05
# ⋮    ⋮       ⋮           ⋮
# 2459 pd_cog  westernized NA
# 2460 pd_pfam westernized NA

# %%
# formatting
lmer_res = lmer_res %>%
    mutate.(Metric = case_when.(Metric == 'nobs' ~ 'No. of obs.',
                                Metric == 'shannon' ~ 'Shannon',
                                Metric == 'pd_cog' ~ 'Faith\'s PD (COG)',
                                Metric == 'pd_pfam' ~ 'Faith\'s PD (Pfam)',
                                Metric == 'pd_phy' ~ 'Faith\'s PD (Phylogeny)',
                                Metric == 'pd_trt' ~ 'Faith\'s PD (Trait)')) 
lmer_res$Metric %>% table
# Out:
# .
#       Faith's PD (COG)      Faith's PD (Pfam) Faith's PD (Phylogeny)
#                    400                    400                    400
#     Faith's PD (Trait)            No. of obs.                Shannon
#                    400                    460                    400

# %% [markdown]
# ## Plotting

# %%
# westernization
p = lmer_res %>%
    filter.(Variable == 'westernized') %>%
    filter.(Padj < 0.01) %>%
    mutate.(mean_F = mean(F_value, na.rm=TRUE), by=list(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8,5)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    filter.(Variable == 'westernized') %>%
    filter.(Metric != 'No. of obs.') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(size=2, alpha=0.2) +
    geom_point(size=2, alpha=0.6, shape='O') +
    scale_color_discrete('Measure') +
    facet_grid(. ~ sig) +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8.2,3.8)
plot(p)
# Out:
# plot without title

# %%
# gender
p = lmer_res %>%
    filter.(Variable == 'gender') %>%
    filter.(Padj < 0.01) %>%
    mutate.(mean_F = mean(F_value, na.rm=TRUE), by=list(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
              Clade = gsub('^(Bacteria|Archaea);', '', Clade),
              Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8,3)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    filter.(Variable == 'gender') %>%
    filter.(Metric != 'No. of obs.') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(size=2, alpha=0.2) +
    geom_point(size=2, alpha=0.6, shape='O') +
    scale_color_discrete('Measure') +
    facet_grid(. ~ sig) +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8.2,2.8)
plot(p)
# Out:
# plot without title

# %%
# age
p = lmer_res %>%
    filter.(Variable == 'age') %>%
    filter.(Padj < 0.01) %>%
    mutate.(mean_F = mean(F_value, na.rm=TRUE), by=list(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
              Clade = gsub('^(Bacteria|Archaea);', '', Clade),
              Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8,3)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    filter.(Variable == 'age') %>%
    filter.(Metric != 'No. of obs.') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(size=2, alpha=0.2) +
    geom_point(size=2, alpha=0.6, shape='O') +
    scale_color_discrete('Measure') +
    facet_grid(. ~ sig) +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8.2,2.8)
plot(p)
# Out:
# plot without title

# %%
# disease status
p = lmer_res %>%
    filter.(Variable == 'disease_status') %>%
    filter.(Padj < 0.01) %>%
    mutate.(mean_F = mean(F_value, na.rm=TRUE), by=list(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
              Clade = gsub('^(Bacteria|Archaea);', '', Clade),
              Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=log10(Padj))) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.6, shape='O') +
    scale_color_continuous('Adj. P\n(log10)', low='blue', high='red') +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    facet_grid(. ~ Metric) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8,3)
plot(p)
# Out:
# plot without title

# %%
p = lmer_res %>%
    filter.(Variable == 'disease_status') %>%
    filter.(Metric != 'No. of obs.') %>%
    mutate.(sig = ifelse(Padj < 0.01, 'Adj. P < 0.01', 'Adj. P >= 0.01')) %>%
    mutate.(any_sig = any(Padj < 0.01), 
            .by=c(Clade)) %>%
    filter.(any_sig == TRUE) %>%
    mutate.(mean_F = mean(F_value), .by=c(Clade)) %>%
    mutate.(Clade = gsub('___', ';', Clade),
            Clade = gsub('^(Bacteria|Archaea);', '', Clade),
            Clade = Clade %>% reorder(mean_F)) %>%
    ggplot(aes(Clade, F_value, color=Metric)) +
    geom_point(size=2, alpha=0.2) +
    geom_point(size=2, alpha=0.6, shape='O') +
    scale_color_discrete('Measure') +
    facet_grid(. ~ sig) +
    labs(x='Phylum;Class;Order;Family', y='F value') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    ) +
    coord_flip() 

p.dims(8.2,3.8)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] LeyLabRMisc_0.1.6 lmerTest_3.1-1    lme4_1.1-23       Matrix_1.2-18
#  [5] PhyloMeasures_2.1 vegan_2.5-6       lattice_0.20-38   permute_0.9-5
#  [9] phyloseq_1.30.0   ape_5.3           tidytable_0.5.6   data.table_1.12.8
# [13] ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.46.0      bit64_0.9-7         jsonlite_1.6
#  [4] splines_3.6.2       foreach_1.4.7       assertthat_0.2.1
#  [7] statmod_1.4.34      stats4_3.6.2        numDeriv_2016.8-1.1
# [10] pillar_1.4.3        glue_1.4.2          uuid_0.1-2
# [13] digest_0.6.23       XVector_0.26.0      minqa_1.2.4
# [16] colorspace_1.4-1    htmltools_0.4.0     plyr_1.8.5
# [19] pkgconfig_2.0.3     zlibbioc_1.32.0     purrr_0.3.3
# [22] scales_1.1.1        RApiSerialize_0.1.0 tibble_2.1.3
# [25] mgcv_1.8-31         farver_2.0.3        IRanges_2.20.0
# [28] ellipsis_0.3.0      withr_2.1.2         repr_1.0.2
# [31] BiocGenerics_0.32.0 lazyeval_0.2.2      survival_3.1-8
# [34] magrittr_1.5        crayon_1.3.4        evaluate_0.14
# [37] doParallel_1.0.15   nlme_3.1-143        MASS_7.3-51.5
# [40] tools_3.6.2         lifecycle_0.2.0     stringr_1.4.0
# [43] Rhdf5lib_1.8.0      S4Vectors_0.24.0    munsell_0.5.0
# [46] cluster_2.1.0       Biostrings_2.54.0   ade4_1.7-13
# [49] compiler_3.6.2      qs_0.21.1           rlang_0.4.9
# [52] rhdf5_2.30.0        grid_3.6.2          nloptr_1.2.2.1
# [55] pbdZMQ_0.3-3        iterators_1.0.12    IRkernel_1.1
# [58] biomformat_1.14.0   igraph_1.2.4.2      labeling_0.3
# [61] base64enc_0.1-3     boot_1.3-25         gtable_0.3.0
# [64] codetools_0.2-16    multtest_2.42.0     reshape2_1.4.3
# [67] R6_2.4.1            bit_1.1-15.1        stringi_1.4.5
# [70] parallel_3.6.2      IRdisplay_0.7.0     Rcpp_1.0.3
# [73] vctrs_0.3.1         tidyselect_1.1.0
